# %%
import yaml
import requests
import datetime
import time
import csv
import pandas as pd
import math

# Get all Venue IDs for venues within the bounding box.


def get_delta(lower, upper, length):
    return (upper - lower)/length


def getBBoxVenuesNWSE(bound_N,bound_W,bound_S,bound_E,divisions,
                 foursquare_id,foursquare_secret):    
    
    lat_delta = get_delta(bound_N,bound_S,divisions)
    long_delta = get_delta(bound_W,bound_E, divisions)
    
    dist_ns=110574*abs(bound_N-bound_S)
    dist_ew=111320*math.cos(math.radians(bound_N))*abs(bound_E-bound_W)
    
    
    search_params = {
        'client_id': foursquare_id,
        'client_secret': foursquare_secret,
  #      'intent': 'browse',
        'limit': 50,
        'v': '20181209',
        'radius' : math.sqrt(dist_ew*dist_ew+dist_ns*dist_ns)/divisions,
        'sortByDistance': 1
        
    }
    
    print('BBox size {}m x {}m. Search r={}m'.format(dist_ns,dist_ew,search_params['radius']))
    

    search_count = 0

    venues_list=[]
        
    max_response_size=0

    for lat in range(divisions):
        for long in range(divisions):
            
            ne_lat = bound_N + lat * lat_delta
            ne_long = bound_W+ (long+1) * long_delta
            
            #search_params.update({'ne': '{},{}'.format(ne_lat, ne_long),
            #                      'sw': '{},{}'.format(ne_lat - lat_delta,
            #                                           ne_long - long_delta)})                          
            
            search_params.update({'ll': '{},{}'.format(ne_lat-0.5*lat_delta, ne_long-0.5*long_delta)})
  
            items=[]
            
            # print(search_params)
            while True:
                try:
                    r = requests.get('https://api.foursquare.com/v2/venues/explore',
                                 params=search_params)
                except requests.exceptions.RequestException as e:  
                    print(e)    
                    print('Sleeping 10s')
                    time.sleep(10)


                try:
                    resp=r.json()['response']
                except:
                    time.sleep(5)
                    print('retry')
                    continue

                if 'groups' in resp:
                    break
                else:
                    time.sleep(5)
                    print('retry')

            #if 'venues' in r.json()['response']:
            #    venues = r.json()['response']['venues']
            items = r.json()['response']['groups'][0]['items']
            time.sleep(0.6)

            # print('Query returned {} items: {}'.format(len(items),items))
            
            for item in items:
                venue=item['venue']
                categories = venue.get('categories', '')
                if len(categories) == 0:
                   categories = ''
                else:
                    categories = ';'.join([x['name'] for x in categories])
               # print(categories)
                venues_list.append([venue['name'], 
                                    venue['id'],
                    venue['location']['lat'], 
                    venue['location']['lng'],  
                    categories]);

            #print('Search retrieved {} venues.'.format(len(items)))
            max_response_size=max(max_response_size,len(items))

            if len(items) >= search_params['limit']:
                print("Recursive split")
                return getBBoxVenuesNWSE(bound_N,bound_W,bound_S,bound_E,2*divisions,
                 foursquare_id,foursquare_secret) 

            search_count += 1
            if search_count % 50 == 0:
                print(search_count)
         
        # gets fussy when more than 5000 requests/hr
    #        if search_count % 5000 == 0:
    #           time.sleep(60*60)

            

    print('{} Unique Venues Scraped: {}.'.format(
        len(venues_list), datetime.datetime.now()))

    print('Maximum response size {} venues.'.format(max_response_size))
    return venues_list

#df=pd.DataFrame(venues_list)
#df.to_csv('tampere_venues.csv',index=False)
#df

def getCenteredVenues(lat,lng,dist_to_side,divisions,foursquare_id,foursquare_secret):

    # convert distance in meters to latitude/longtitude deltas    
    
    delta_lat=dist_to_side/110574
    delta_lng=dist_to_side/(111320*math.cos(math.radians(lat)))
    
    return getBBoxVenuesNWSE(lat+delta_lat,lng-delta_lng,lat-delta_lat,lng+delta_lng,divisions,
                 foursquare_id,foursquare_secret)

def scrapeNamedCity(city,df,foursquare_id,foursquare_secret):
    from geopy.geocoders import Nominatim

    geolocator = Nominatim(user_agent="my-application")

    while True:
        try:
            location = geolocator.geocode(city)
        except:
            time.sleep(3)
            continue
        else:
            break
            
    lat= location.latitude
    lng = location.longitude
    dist_to_side=3000# meters
    print('The geographical coordinates of {} city centre are {}, {}.'.format(city,lat,lng))
    
    # convert distance in meters to latitude/longtitude deltas    
    
    delta_lat=2*dist_to_side/110574
    delta_lng=2*dist_to_side/(111320*math.cos(math.radians(lat)))
    
    
    divisions=math.ceil(2*25*dist_to_side/3000)

    processed_cities = set()

    if len(df)>0:
        processed_cities=set(df['City'].unique())
  
    for step_lat in range(9):
        for step_long in range(9):
            
            lat_tile = lat + (step_lat-4) * delta_lat
            long_tile = lng + (step_long-4) * delta_lng
            
            city_string = '{}-{}-{}'.format(city,step_lat,step_long)
 
            if city_string in processed_cities:
                print('Skipping {}'.format(city_string))
            else:
                print('Processing {}', format(city_string))
                venues_list=getCenteredVenues(lat_tile,long_tile,dist_to_side,divisions,CLIENT_ID,CLIENT_SECRET)
                if len(venues_list) > 0:
                    dfn=pd.DataFrame(venues_list)
                    print(dfn.shape)
                    dfn.drop_duplicates(inplace=True)
                    dfn.columns=['Name','Id','Latitude','Longtitude','Categories']
                    dfn['City']=city_string

                    print(dfn.shape)

                    if df.size > 0:
                       df=df.append(dfn,ignore_index=True)
                    else:
                       df=dfn
            df.to_csv(FILENAME,index=False)
                        
    return df

# %%
import pandas as pd
import os
import math
import numpy as np # library to handle data in a vectorized manner
# !conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library

# !conda install -c conda-forge geopy --yes 
# uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import matplotlib.cm as cm
import matplotlib.colors as colors


print('Libraries imported.')

# %%
CLIENT_ID = 'U1ND1RSESM34E0F5N2VX0WIY1TSNYQM41LXUBM523HOLJXCV' # your Foursquare ID
CLIENT_SECRET = 'X0KNHD5JZDI4XS0TJLWZPZ5AGC44KHUB4J0STYMT2R5MEKPV' # your Foursquare Secret

#kaisa 
CLIENT_ID='HPVS5YBLFPA0AQ1OZOM42KQQ4EHFRUVO1DZS00ENE0HPUI0A'
CLIENT_SECRET='250O40DSBBEP53FPSDEIDBVINQ3VZD4G5SHHHYHPEGIMRGDR'

FILENAME='scraped_venues_tiled.csv'

cities_list=[
    "London, England",
    "Berlin, Germany",
    "Rome, Italy"
]

#cities_list=[
#   "Cremona, Italy"
#]


cities_list_test=['Pori, Finland',"Lappeenranta, Finland"]

df=pd.DataFrame()
try:
    df=pd.read_csv(FILENAME)
except:
    pass

for city in cities_list:
        
    print('city {}'.format(city))
    df=scrapeNamedCity(city,df,CLIENT_ID,CLIENT_SECRET)
    print(df.shape)
    df.to_csv(FILENAME,index=False)
df
# Out:
# city London, England
# The geographical coordinates of London, England city centre are 51.5073219, -0.1276474.
# Skipping London, England-0-0
# Skipping London, England-0-1
# Skipping London, England-0-2
# Skipping London, England-0-3
# Skipping London, England-0-4
# Skipping London, England-0-5
# Skipping London, England-0-6
# Skipping London, England-0-7
# Skipping London, England-0-8
# Skipping London, England-1-0
# Skipping Berlin, Germany-3-0
# Skipping Berlin, Germany-3-1
# Skipping Berlin, Germany-3-2
# Skipping Berlin, Germany-3-3
# Skipping Berlin, Germany-3-4
# Skipping Berlin, Germany-3-5
# Skipping Berlin, Germany-3-6
# Skipping Berlin, Germany-3-7
# Skipping Berlin, Germany-3-8
# Skipping Berlin, Germany-4-0
# Skipping Berlin, Germany-4-1
# Skipping Berlin, Germany-4-2
# Skipping Berlin, Germany-4-3
# Skipping Berlin, Germany-4-4
# Skipping Berlin, Germany-4-5
# Skipping Berlin, Germany-4-6
# Skipping Berlin, Germany-4-7
# Skipping Berlin, Germany-4-8
# Skipping Berlin, Germany-5-0
# Skipping Berlin, Germany-5-1
# Skipping Berlin, Germany-5-2
# Skipping Berlin, Germany-5-3
# Skipping Berlin, Germany-5-4
# Skipping Berlin, Germany-5-5
# Skipping Berlin, Germany-5-6
# Skipping Berlin, Germany-5-7
# Skipping Berlin, Germany-5-8
# Skipping Berlin, Germany-6-0
# Skipping Berlin, Germany-6-1
# Skipping Berlin, Germany-6-2
# Skipping Berlin, Germany-6-3
# Skipping Berlin, Germany-6-4
# Skipping Berlin, Germany-6-5
# Skipping Berlin, Germany-6-6
# Skipping Berlin, Germany-6-7
# Skipping Berlin, Germany-6-8
# Skipping Berlin, Germany-7-0
# Skipping Berlin, Germany-7-1
# Skipping Berlin, Germany-7-2
# Skipping Berlin, Germany-7-3
# Skipping Berlin, Germany-7-4
# Skipping Berlin, Germany-7-5
# Skipping Berlin, Germany-7-6
# Skipping Berlin, Germany-7-7
# Skipping Berlin, Germany-7-8
# Skipping Berlin, Germany-8-0
# Skipping Berlin, Germany-8-1
# Skipping Berlin, Germany-8-2
# Skipping Berlin, Germany-8-3
# Skipping Berlin, Germany-8-4
# Skipping Berlin, Germany-8-5
# Skipping Berlin, Germany-8-6
# Skipping Berlin, Germany-8-7
# Skipping Berlin, Germany-8-8
# (63475, 6)
# city Rome, Italy
# The geographical coordinates of Rome, Italy city centre are 41.894802, 12.4853384.
# Processing {} Rome, Italy-0-0
# BBox size 5999.999999999698m x 5997.469917663032m. Search r=169.66985049002596m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# retry
# 1000
# retry
# 1050
# retry
# 1100
# 1150
# 1200
# 1250
# retry
# retry
# retry
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# retry
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 0 Unique Venues Scraped: 2019-10-01 14:56:52.579065.
# Maximum response size 0 venues.
# Processing {} Rome, Italy-0-1
# BBox size 5999.999999999698m x 5997.469917663032m. Search r=169.66985049002596m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# retry
# retry
# 2100
# retry
# 2150
# 2200
# 2250
# 2300
# 2350
# retry
# retry
# 2400
# 2450
# retry
# 2500
# 0 Unique Venues Scraped: 2019-10-01 15:39:21.909977.
# Maximum response size 0 venues.
# Processing {} Rome, Italy-0-2
# BBox size 5999.999999999698m x 5997.469917663032m. Search r=169.66985049002596m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 145 Unique Venues Scraped: 2019-10-01 16:19:54.240982.
# Maximum response size 6 venues.
# (145, 5)
# (29, 6)
# Processing {} Rome, Italy-0-3
# BBox size 5999.999999999698m x 5997.469917663032m. Search r=169.66985049002596m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# retry
# retry
# 700
# 750
# 800
# 850
# 900
# retry
# retry
# 950
# retry
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# retry
# 1300
# retry
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 297 Unique Venues Scraped: 2019-10-01 17:02:42.517397.
# Maximum response size 6 venues.
# (297, 5)
# (53, 6)
# Processing {} Rome, Italy-0-4
# BBox size 5999.999999999698m x 5997.469917663032m. Search r=169.66985049002596m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# retry
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# retry
# retry
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# retry
# 2400
# 2450
# 2500
# 821 Unique Venues Scraped: 2019-10-01 17:45:08.559786.
# Maximum response size 6 venues.
# (821, 5)
# (158, 6)
# Processing {} Rome, Italy-0-5
# BBox size 5999.999999999698m x 5997.469917663032m. Search r=169.66985049002596m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 200 Unique Venues Scraped: 2019-10-01 18:25:30.539713.
# Maximum response size 3 venues.
# (200, 5)
# (44, 6)
# Processing {} Rome, Italy-0-6
# BBox size 5999.999999999698m x 5997.469917663032m. Search r=169.66985049002596m
# 50
# 100
# 150
# 200
# 250
# 300
# retry
# retry
# retry
# 350
# 400
# 450
# 500
# 550
# 600
# retry
# retry
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# retry
# retry
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# retry
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# retry
# 2350
# 2400
# 2450
# 2500
# 344 Unique Venues Scraped: 2019-10-01 19:08:23.483704.
# Maximum response size 4 venues.
# (344, 5)
# (59, 6)
# Processing {} Rome, Italy-0-7
# BBox size 5999.999999999698m x 5997.469917663032m. Search r=169.66985049002596m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# retry
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# retry
# 1350
# retry
# retry
# 1400
# 1450
# 1500
# 1550
# 1600
# retry
# retry
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 333 Unique Venues Scraped: 2019-10-01 19:51:48.487839.
# Maximum response size 7 venues.
# (333, 5)
# (63, 6)
# Processing {} Rome, Italy-0-8
# BBox size 5999.999999999698m x 5997.469917663032m. Search r=169.66985049002596m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# retry
# 2400
# retry
# retry
# 2450
# 2500
# 729 Unique Venues Scraped: 2019-10-01 20:33:37.793332.
# Maximum response size 7 venues.
# (729, 5)
# (129, 6)
# Processing {} Rome, Italy-1-0
# BBox size 5999.999999999698m x 5997.465090209195m. Search r=169.66978223393156m
# 50
# 100
# retry
# 150
# retry
# retry
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 86 Unique Venues Scraped: 2019-10-01 21:15:05.220905.
# Maximum response size 6 venues.
# (86, 5)
# (19, 6)
# Processing {} Rome, Italy-1-1
# BBox size 5999.999999999698m x 5997.465090209195m. Search r=169.66978223393156m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# retry
# 950
# retry
# 1000
# 1050
# 1100
# 1150
# retry
# 1200
# retry
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# retry
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2001 Unique Venues Scraped: 2019-10-01 21:58:05.750902.
# Maximum response size 26 venues.
# (2001, 5)
# (372, 6)
# Processing {} Rome, Italy-1-2
# BBox size 5999.999999999698m x 5997.465090209491m. Search r=169.66978223393573m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# retry
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# retry
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# retry
# 2000
# retry
# 2050
# 2100
# 2150
# 2200
# 2250
# retry
# 2300
# 2350
# 2400
# 2450
# 2500
# 1256 Unique Venues Scraped: 2019-10-01 22:40:19.063799.
# Maximum response size 7 venues.
# (1256, 5)
# (235, 6)
# Processing {} Rome, Italy-1-3
# BBox size 5999.999999999698m x 5997.465090209491m. Search r=169.66978223393573m
# 50
# 100
# retry
# 150
# 200
# 250
# retry
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# retry
# 2450
# 2500
# 501 Unique Venues Scraped: 2019-10-01 23:21:32.311526.
# Maximum response size 29 venues.
# (501, 5)
# (94, 6)
# Processing {} Rome, Italy-1-4
# BBox size 5999.999999999698m x 5997.465090209195m. Search r=169.66978223393156m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# retry
# retry
# 650
# 700
# 750
# 800
# 850
# retry
# 900
# retry
# 950
# retry
# 1000
# 1050
# 1100
# 1150
# retry
# 1200
# retry
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# retry
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 173 Unique Venues Scraped: 2019-10-02 00:04:08.926671.
# Maximum response size 4 venues.
# (173, 5)
# (31, 6)
# Processing {} Rome, Italy-1-5
# BBox size 5999.999999999698m x 5997.465090209491m. Search r=169.66978223393573m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# retry
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# retry
# 1600
# 1650
# retry
# 1700
# 1750
# 1800
# 1850
# retry
# 1900
# retry
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 192 Unique Venues Scraped: 2019-10-02 00:46:59.504693.
# Maximum response size 3 venues.
# (192, 5)
# (38, 6)
# Processing {} Rome, Italy-1-6
# BBox size 5999.999999999698m x 5997.465090209491m. Search r=169.66978223393573m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1133 Unique Venues Scraped: 2019-10-02 01:27:22.374549.
# Maximum response size 12 venues.
# (1133, 5)
# (207, 6)
# Processing {} Rome, Italy-1-7
# BBox size 5999.999999999698m x 5997.465090209195m. Search r=169.66978223393156m
# 50
# 100
# 150
# 200
# retry
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# retry
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 734 Unique Venues Scraped: 2019-10-02 02:08:56.562070.
# Maximum response size 16 venues.
# (734, 5)
# (147, 6)
# Processing {} Rome, Italy-1-8
# BBox size 5999.999999999698m x 5997.465090209195m. Search r=169.66978223393156m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# retry
# retry
# retry
# 1350
# 1400
# 1450
# 1500
# 1550
# retry
# 1600
# retry
# retry
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 83 Unique Venues Scraped: 2019-10-02 02:51:18.713996.
# Maximum response size 2 venues.
# (83, 5)
# (14, 6)
# Processing {} Rome, Italy-2-0
# BBox size 5999.999999999698m x 5997.460254592647m. Search r=169.66971386245083m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# retry
# retry
# retry
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# retry
# retry
# 2450
# 2500
# 600 Unique Venues Scraped: 2019-10-02 03:32:41.492396.
# Maximum response size 10 venues.
# (600, 5)
# (124, 6)
# Processing {} Rome, Italy-2-1
# BBox size 5999.999999999698m x 5997.460254592647m. Search r=169.66971386245083m
# 50
# 100
# 150
# retry
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# retry
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1888 Unique Venues Scraped: 2019-10-02 04:13:58.247512.
# Maximum response size 24 venues.
# (1888, 5)
# (347, 6)
# Processing {} Rome, Italy-2-2
# BBox size 5999.999999999698m x 5997.460254592647m. Search r=169.66971386245083m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# retry
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# retry
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1205 Unique Venues Scraped: 2019-10-02 04:55:42.090914.
# Maximum response size 7 venues.
# (1205, 5)
# (225, 6)
# Processing {} Rome, Italy-2-3
# BBox size 5999.999999999698m x 5997.460254592647m. Search r=169.66971386245083m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# retry
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# retry
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# retry
# retry
# 2500
# 1246 Unique Venues Scraped: 2019-10-02 05:37:37.524650.
# Maximum response size 9 venues.
# (1246, 5)
# (254, 6)
# Processing {} Rome, Italy-2-4
# BBox size 5999.999999999698m x 5997.460254592647m. Search r=169.66971386245083m
# 50
# 100
# 150
# 200
# 250
# 300
# retry
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 928 Unique Venues Scraped: 2019-10-02 06:18:21.318848.
# Maximum response size 6 venues.
# (928, 5)
# (175, 6)
# Processing {} Rome, Italy-2-5
# BBox size 5999.999999999698m x 5997.460254592647m. Search r=169.66971386245083m
# 50
# 100
# retry
# 150
# 200
# retry
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# retry
# retry
# retry
# 650
# 700
# 750
# 800
# retry
# 850
# 900
# retry
# 950
# retry
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 674 Unique Venues Scraped: 2019-10-02 07:02:10.191328.
# Maximum response size 10 venues.
# (674, 5)
# (128, 6)
# Processing {} Rome, Italy-2-6
# BBox size 5999.999999999698m x 5997.460254592647m. Search r=169.66971386245083m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# retry
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# retry
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1568 Unique Venues Scraped: 2019-10-02 07:43:46.529794.
# Maximum response size 8 venues.
# (1568, 5)
# (295, 6)
# Processing {} Rome, Italy-2-7
# BBox size 5999.999999999698m x 5997.460254592647m. Search r=169.66971386245083m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1163 Unique Venues Scraped: 2019-10-02 08:24:08.494532.
# Maximum response size 17 venues.
# (1163, 5)
# (221, 6)
# Processing {} Rome, Italy-2-8
# BBox size 5999.999999999698m x 5997.460254592647m. Search r=169.66971386245083m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# retry
# retry
# 400
# retry
# 450
# 500
# 550
# 600
# 650
# 700
# retry
# 750
# 800
# 850
# 900
# 950
# 1000
# retry
# 1050
# retry
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 204 Unique Venues Scraped: 2019-10-02 09:06:30.580955.
# Maximum response size 3 venues.
# (204, 5)
# (36, 6)
# Processing {} Rome, Italy-3-0
# BBox size 5999.999999999698m x 5997.455410783792m. Search r=169.66964537516563m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# retry
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# retry
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# retry
# 2100
# retry
# 2150
# retry
# 2200
# 2250
# retry
# 2300
# 2350
# 2400
# 2450
# 2500
# 857 Unique Venues Scraped: 2019-10-02 09:48:49.597025.
# Maximum response size 9 venues.
# (857, 5)
# (155, 6)
# Processing {} Rome, Italy-3-1
# BBox size 5999.999999999698m x 5997.455410783792m. Search r=169.66964537516563m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 158 Unique Venues Scraped: 2019-10-02 10:29:03.108490.
# Maximum response size 2 venues.
# (158, 5)
# (30, 6)
# Processing {} Rome, Italy-3-2
# BBox size 5999.999999999698m x 5997.455410783792m. Search r=169.66964537516563m
# 50
# 100
# retry
# retry
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 416 Unique Venues Scraped: 2019-10-02 11:10:21.924723.
# Maximum response size 6 venues.
# (416, 5)
# (76, 6)
# Processing {} Rome, Italy-3-3
# BBox size 5999.999999999698m x 5997.455410783792m. Search r=169.66964537516563m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# retry
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# retry
# retry
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1828 Unique Venues Scraped: 2019-10-02 11:52:11.182449.
# Maximum response size 12 venues.
# (1828, 5)
# (354, 6)
# Processing {} Rome, Italy-3-4
# BBox size 5999.999999999698m x 5997.455410783792m. Search r=169.66964537516563m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# retry
# retry
# 2400
# 2450
# 2500
# 4972 Unique Venues Scraped: 2019-10-02 12:34:16.204520.
# Maximum response size 34 venues.
# (4972, 5)
# (938, 6)
# Processing {} Rome, Italy-3-5
# BBox size 5999.999999999698m x 5997.455410783792m. Search r=169.66964537516563m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# retry
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2722 Unique Venues Scraped: 2019-10-02 13:16:00.303519.
# Maximum response size 13 venues.
# (2722, 5)
# (517, 6)
# Processing {} Rome, Italy-3-6
# BBox size 5999.999999999698m x 5997.455410783792m. Search r=169.66964537516563m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# retry
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# retry
# retry
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2145 Unique Venues Scraped: 2019-10-02 13:58:31.554104.
# Maximum response size 12 venues.
# (2145, 5)
# (404, 6)
# Processing {} Rome, Italy-3-7
# BBox size 5999.999999999698m x 5997.455410783792m. Search r=169.66964537516563m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# retry
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# retry
# 2300
# 2350
# 2400
# 2450
# 2500
# 732 Unique Venues Scraped: 2019-10-02 14:40:17.469533.
# Maximum response size 5 venues.
# (732, 5)
# (130, 6)
# Processing {} Rome, Italy-3-8
# BBox size 5999.999999999698m x 5997.455410783792m. Search r=169.66964537516563m
# 50
# 100
# retry
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 420 Unique Venues Scraped: 2019-10-02 15:20:53.498955.
# Maximum response size 5 venues.
# (420, 5)
# (71, 6)
# Processing {} Rome, Italy-4-0
# BBox size 5999.999999999698m x 5997.4505587530775m. Search r=169.66957677165814m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# retry
# retry
# 650
# 700
# 750
# retry
# 800
# retry
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# retry
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 387 Unique Venues Scraped: 2019-10-02 16:03:06.464259.
# Maximum response size 5 venues.
# (387, 5)
# (70, 6)
# Processing {} Rome, Italy-4-1
# BBox size 5999.999999999698m x 5997.4505587530775m. Search r=169.66957677165814m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# retry
# 1650
# 1700
# retry
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# retry
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# retry
# 2400
# 2450
# 2500
# 183 Unique Venues Scraped: 2019-10-02 16:44:55.479077.
# Maximum response size 3 venues.
# (183, 5)
# (32, 6)
# Processing {} Rome, Italy-4-2
# BBox size 5999.999999999698m x 5997.4505587530775m. Search r=169.66957677165814m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# retry
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 525 Unique Venues Scraped: 2019-10-02 17:25:07.231361.
# Maximum response size 5 venues.
# (525, 5)
# (98, 6)
# Processing {} Rome, Italy-4-3
# BBox size 5999.999999999698m x 5997.4505587530775m. Search r=169.66957677165814m
# 50
# 100
# 150
# 200
# 250
# 300
# retry
# 350
# retry
# 400
# 450
# 500
# 550
# 600
# retry
# 650
# retry
# 700
# 750
# 800
# 850
# 900
# 950
# retry
# retry
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 3730 Unique Venues Scraped: 2019-10-02 18:07:58.605871.
# Maximum response size 13 venues.
# (3730, 5)
# (720, 6)
# Processing {} Rome, Italy-4-4
# BBox size 5999.999999999698m x 5997.4505587530775m. Search r=169.66957677165814m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# Recursive split
# BBox size 5999.999999999698m x 5997.4505587530775m. Search r=84.83478838582907m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# retry
# 450
# 500
# 550
# 600
# 650
# 700
# retry
# 750
# 800
# 850
# 900
# 950
# 1000
# retry
# retry
# 1050
# retry
# 1100
# 1150
# retry
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# retry
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800
# 3850
# 3900
# 3950
# retry
# 4000
# 4050
# 4100
# 4150
# 4200
# retry
# 4250
# 4300
# 4350
# 4400
# 4450
# 4500
# 4550
# retry
# 4600
# 4650
# 4700
# 4750
# 4800
# 4850
# 4900
# 4950
# 5000
# 5050
# 5100
# 5150
# 5200
# 5250
# 5300
# 5350
# 5400
# 5450
# 5500
# 5550
# 5600
# 5650
# 5700
# 5750
# 5800
# 5850
# 5900
# 5950
# 6000
# 6050
# 6100
# 6150
# 6200
# 6250
# 6300
# 6350
# 6400
# 6450
# 6500
# 6550
# 6600
# 6650
# 6700
# 6750
# 6800
# 6850
# 6900
# 6950
# 7000
# 7050
# 7100
# 7150
# 7200
# 7250
# 7300
# 7350
# retry
# retry
# retry
# 7400
# retry
# 7450
# 7500
# 7550
# 7600
# 7650
# 7700
# 7750
# 7800
# 7850
# 7900
# retry
# 7950
# retry
# 8000
# retry
# retry
# retry
# 8050
# 8100
# retry
# 8150
# 8200
# 8250
# retry
# 8300
# 8350
# 8400
# 8450
# 8500
# 8550
# 8600
# 8650
# 8700
# 8750
# 8800
# 8850
# 8900
# 8950
# 9000
# 9050
# 9100
# 9150
# 9200
# 9250
# 9300
# 9350
# 9400
# 9450
# 9500
# 9550
# 9600
# 9650
# 9700
# 9750
# 9800
# 9850
# 9900
# 9950
# 10000
# 20825 Unique Venues Scraped: 2019-10-02 21:16:36.227915.
# Maximum response size 24 venues.
# (20825, 5)
# (3571, 6)
# Processing {} Rome, Italy-4-5
# BBox size 5999.999999999698m x 5997.4505587530775m. Search r=169.66957677165814m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# retry
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# retry
# 900
# retry
# 950
# 1000
# 1050
# 1100
# 1150
# retry
# 1200
# 1250
# 1300
# 1350
# 1400
# retry
# 1450
# retry
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 4872 Unique Venues Scraped: 2019-10-02 22:00:11.199796.
# Maximum response size 23 venues.
# (4872, 5)
# (961, 6)
# Processing {} Rome, Italy-4-6
# BBox size 5999.999999999698m x 5997.4505587530775m. Search r=169.66957677165814m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# retry
# retry
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1310 Unique Venues Scraped: 2019-10-02 22:41:51.634454.
# Maximum response size 28 venues.
# (1310, 5)
# (243, 6)
# Processing {} Rome, Italy-4-7
# BBox size 5999.999999999698m x 5997.4505587530775m. Search r=169.66957677165814m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 504 Unique Venues Scraped: 2019-10-02 23:23:01.167415.
# Maximum response size 4 venues.
# (504, 5)
# (91, 6)
# Processing {} Rome, Italy-4-8
# BBox size 5999.999999999698m x 5997.4505587530775m. Search r=169.66957677165814m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# retry
# retry
# retry
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# retry
# 1100
# retry
# retry
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 116 Unique Venues Scraped: 2019-10-03 00:06:04.799466.
# Maximum response size 3 venues.
# (116, 5)
# (21, 6)
# Processing {} Rome, Italy-5-0
# BBox size 5999.999999999698m x 5997.445698471015m. Search r=169.66950805151154m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# retry
# 1550
# 1600
# retry
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# retry
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 116 Unique Venues Scraped: 2019-10-03 00:48:11.565806.
# Maximum response size 2 venues.
# (116, 5)
# (21, 6)
# Processing {} Rome, Italy-5-1
# BBox size 5999.999999999698m x 5997.445698471015m. Search r=169.66950805151154m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 92 Unique Venues Scraped: 2019-10-03 01:28:42.347732.
# Maximum response size 2 venues.
# (92, 5)
# (16, 6)
# Processing {} Rome, Italy-5-2
# BBox size 5999.999999999698m x 5997.445698471015m. Search r=169.66950805151154m
# 50
# retry
# 100
# 150
# retry
# 200
# 250
# 300
# 350
# 400
# retry
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# retry
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 302 Unique Venues Scraped: 2019-10-03 02:10:34.070913.
# Maximum response size 5 venues.
# (302, 5)
# (62, 6)
# Processing {} Rome, Italy-5-3
# BBox size 5999.999999999698m x 5997.445698471015m. Search r=169.66950805151154m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# retry
# retry
# retry
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# retry
# 1250
# retry
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# retry
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1912 Unique Venues Scraped: 2019-10-03 02:52:51.294055.
# Maximum response size 8 venues.
# (1912, 5)
# (362, 6)
# Processing {} Rome, Italy-5-4
# BBox size 5999.999999999698m x 5997.445698471015m. Search r=169.66950805151154m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# retry
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# retry
# 1950
# 2000
# 2050
# retry
# 2100
# 2150
# 2200
# retry
# 2250
# retry
# retry
# retry
# 2300
# 2350
# 2400
# 2450
# 2500
# 3874 Unique Venues Scraped: 2019-10-03 03:35:10.880436.
# Maximum response size 25 venues.
# (3874, 5)
# (741, 6)
# Processing {} Rome, Italy-5-5
# BBox size 5999.999999999698m x 5997.445698471015m. Search r=169.66950805151154m
# 50
# retry
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# retry
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# retry
# retry
# 800
# retry
# retry
# retry
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 3126 Unique Venues Scraped: 2019-10-03 04:17:33.748963.
# Maximum response size 33 venues.
# (3126, 5)
# (602, 6)
# Processing {} Rome, Italy-5-6
# BBox size 5999.999999999698m x 5997.445698471015m. Search r=169.66950805151154m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# retry
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# retry
# 1500
# retry
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1033 Unique Venues Scraped: 2019-10-03 04:59:09.595242.
# Maximum response size 6 venues.
# (1033, 5)
# (185, 6)
# Processing {} Rome, Italy-5-7
# BBox size 5999.999999999698m x 5997.445698471015m. Search r=169.66950805151154m
# 50
# 100
# retry
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# retry
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# retry
# 1950
# retry
# 2000
# 2050
# 2100
# 2150
# 2200
# retry
# 2250
# retry
# 2300
# 2350
# 2400
# 2450
# 2500
# 642 Unique Venues Scraped: 2019-10-03 05:40:42.753951.
# Maximum response size 5 venues.
# (642, 5)
# (117, 6)
# Processing {} Rome, Italy-5-8
# BBox size 5999.999999999698m x 5997.445698471015m. Search r=169.66950805151154m
# 50
# 100
# retry
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 890 Unique Venues Scraped: 2019-10-03 06:21:20.740606.
# Maximum response size 10 venues.
# (890, 5)
# (168, 6)
# Processing {} Rome, Italy-6-0
# BBox size 5999.999999999698m x 5997.440829907604m. Search r=169.66943921430186m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# retry
# 550
# retry
# retry
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# retry
# 1250
# retry
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# retry
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 92 Unique Venues Scraped: 2019-10-03 07:03:39.986896.
# Maximum response size 3 venues.
# (92, 5)
# (15, 6)
# Processing {} Rome, Italy-6-1
# BBox size 5999.999999999698m x 5997.440829907604m. Search r=169.66943921430186m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# retry
# 1650
# retry
# 1700
# retry
# 1750
# 1800
# 1850
# 1900
# 1950
# retry
# retry
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# retry
# retry
# 2350
# 2400
# 2450
# 2500
# 38 Unique Venues Scraped: 2019-10-03 07:46:07.351508.
# Maximum response size 2 venues.
# (38, 5)
# (6, 6)
# Processing {} Rome, Italy-6-2
# BBox size 5999.999999999698m x 5997.440829907604m. Search r=169.66943921430186m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 237 Unique Venues Scraped: 2019-10-03 08:26:17.522426.
# Maximum response size 5 venues.
# (237, 5)
# (50, 6)
# Processing {} Rome, Italy-6-3
# BBox size 5999.999999999698m x 5997.440829907604m. Search r=169.66943921430186m
# 50
# 100
# 150
# 200
# 250
# retry
# 300
# retry
# 350
# 400
# 450
# 500
# retry
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# retry
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 508 Unique Venues Scraped: 2019-10-03 09:08:25.828932.
# Maximum response size 6 venues.
# (508, 5)
# (96, 6)
# Processing {} Rome, Italy-6-4
# BBox size 5999.999999999698m x 5997.440829907604m. Search r=169.66943921430186m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# retry
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# retry
# retry
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# retry
# retry
# retry
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# retry
# 2000
# 2050
# 2100
# 2150
# retry
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 910 Unique Venues Scraped: 2019-10-03 09:51:51.420478.
# Maximum response size 6 venues.
# (910, 5)
# (160, 6)
# Processing {} Rome, Italy-6-5
# BBox size 5999.999999999698m x 5997.440829907604m. Search r=169.66943921430186m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# retry
# 2400
# 2450
# retry
# 2500
# 219 Unique Venues Scraped: 2019-10-03 10:33:00.682345.
# Maximum response size 5 venues.
# (219, 5)
# (39, 6)
# Processing {} Rome, Italy-6-6
# BBox size 5999.999999999698m x 5997.440829907604m. Search r=169.66943921430186m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# retry
# retry
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 435 Unique Venues Scraped: 2019-10-03 11:14:15.075442.
# Maximum response size 5 venues.
# (435, 5)
# (78, 6)
# Processing {} Rome, Italy-6-7
# BBox size 5999.999999999698m x 5997.440829907604m. Search r=169.66943921430186m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# retry
# retry
# retry
# retry
# 1000
# retry
# 1050
# 1100
# 1150
# 1200
# 1250
# retry
# retry
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# retry
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 345 Unique Venues Scraped: 2019-10-03 11:57:36.851723.
# Maximum response size 4 venues.
# (345, 5)
# (61, 6)
# Processing {} Rome, Italy-6-8
# BBox size 5999.999999999698m x 5997.440829907604m. Search r=169.66943921430186m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# retry
# 1950
# retry
# 2000
# retry
# retry
# retry
# retry
# 2050
# 2100
# retry
# retry
# retry
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 191 Unique Venues Scraped: 2019-10-03 12:40:26.900722.
# Maximum response size 3 venues.
# (191, 5)
# (35, 6)
# Processing {} Rome, Italy-7-0
# BBox size 5999.999999999698m x 5997.435953032946m. Search r=169.66937025960644m
# 50
# 100
# retry
# 150
# 200
# 250
# 300
# 350
# 400
# retry
# 450
# 500
# retry
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 177 Unique Venues Scraped: 2019-10-03 13:21:05.379059.
# Maximum response size 5 venues.
# (177, 5)
# (30, 6)
# Processing {} Rome, Italy-7-1
# BBox size 5999.999999999698m x 5997.435953032946m. Search r=169.66937025960644m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# retry
# retry
# retry
# 600
# retry
# 650
# 700
# 750
# 800
# 850
# retry
# retry
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# retry
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 321 Unique Venues Scraped: 2019-10-03 14:03:46.503324.
# Maximum response size 4 venues.
# (321, 5)
# (56, 6)
# Processing {} Rome, Italy-7-2
# BBox size 5999.999999999698m x 5997.435953032946m. Search r=169.66937025960644m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# retry
# 1650
# retry
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# retry
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# retry
# 2350
# retry
# 2400
# 2450
# 2500
# 348 Unique Venues Scraped: 2019-10-03 14:46:22.268812.
# Maximum response size 5 venues.
# (348, 5)
# (64, 6)
# Processing {} Rome, Italy-7-3
# BBox size 5999.999999999698m x 5997.435953032946m. Search r=169.66937025960644m
# 50
# retry
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# retry
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 290 Unique Venues Scraped: 2019-10-03 15:26:57.841848.
# Maximum response size 4 venues.
# (290, 5)
# (54, 6)
# Processing {} Rome, Italy-7-4
# BBox size 5999.999999999698m x 5997.435953032946m. Search r=169.66937025960644m
# 50
# 100
# 150
# retry
# 200
# retry
# 250
# 300
# 350
# 400
# 450
# 500
# retry
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# retry
# retry
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 194 Unique Venues Scraped: 2019-10-03 16:09:29.456920.
# Maximum response size 4 venues.
# (194, 5)
# (36, 6)
# Processing {} Rome, Italy-7-5
# BBox size 5999.999999999698m x 5997.435953032946m. Search r=169.66937025960644m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# retry
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# retry
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 357 Unique Venues Scraped: 2019-10-03 16:51:02.515141.
# Maximum response size 6 venues.
# (357, 5)
# (60, 6)
# Processing {} Rome, Italy-7-6
# BBox size 5999.999999999698m x 5997.435953032946m. Search r=169.66937025960644m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# retry
# 2450
# retry
# 2500
# 724 Unique Venues Scraped: 2019-10-03 17:32:18.665873.
# Maximum response size 6 venues.
# (724, 5)
# (129, 6)
# Processing {} Rome, Italy-7-7
# BBox size 5999.999999999698m x 5997.435953032946m. Search r=169.66937025960644m
# 50
# 100
# 150
# 200
# 250
# retry
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 77 Unique Venues Scraped: 2019-10-03 18:13:39.847693.
# Maximum response size 1 venues.
# (77, 5)
# (13, 6)
# Processing {} Rome, Italy-7-8
# BBox size 5999.999999999698m x 5997.435953032946m. Search r=169.66937025960644m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# retry
# 1050
# retry
# retry
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# retry
# 1700
# retry
# retry
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 66 Unique Venues Scraped: 2019-10-03 18:56:06.577752.
# Maximum response size 4 venues.
# (66, 5)
# (12, 6)
# Processing {} Rome, Italy-8-0
# BBox size 5999.999999999698m x 5997.4310678169295m. Search r=169.66930118699977m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# retry
# 2150
# retry
# retry
# retry
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# retry
# retry
# 2500
# 451 Unique Venues Scraped: 2019-10-03 19:37:43.861904.
# Maximum response size 8 venues.
# (451, 5)
# (85, 6)
# Processing {} Rome, Italy-8-1
# BBox size 5999.999999999698m x 5997.4310678169295m. Search r=169.66930118699977m
# 50
# 100
# 150
# 200
# 250
# 300
# retry
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 290 Unique Venues Scraped: 2019-10-03 20:18:08.920332.
# Maximum response size 7 venues.
# (290, 5)
# (55, 6)
# Processing {} Rome, Italy-8-2
# BBox size 5999.999999999698m x 5997.4310678169295m. Search r=169.66930118699977m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# retry
# retry
# 800
# 850
# 900
# 950
# 1000
# 1050
# retry
# retry
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 148 Unique Venues Scraped: 2019-10-03 21:00:38.076903.
# Maximum response size 3 venues.
# (148, 5)
# (28, 6)
# Processing {} Rome, Italy-8-3
# BBox size 5999.999999999698m x 5997.4310678169295m. Search r=169.66930118699977m
# 50
# 100
# 150
# 200
# 250
# retry
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# retry
# 1800
# retry
# retry
# 1850
# retry
# retry
# 1900
# 1950
# 2000
# 2050
# 2100
# retry
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# retry
# retry
# 2500
# 145 Unique Venues Scraped: 2019-10-03 21:42:53.993500.
# Maximum response size 5 venues.
# (145, 5)
# (29, 6)
# Processing {} Rome, Italy-8-4
# BBox size 5999.999999999698m x 5997.4310678169295m. Search r=169.66930118699977m
# retry
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 180 Unique Venues Scraped: 2019-10-03 22:23:48.487129.
# Maximum response size 4 venues.
# (180, 5)
# (34, 6)
# Processing {} Rome, Italy-8-5
# BBox size 5999.999999999698m x 5997.4310678169295m. Search r=169.66930118699977m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# retry
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# retry
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 335 Unique Venues Scraped: 2019-10-03 23:05:44.356828.
# Maximum response size 6 venues.
# (335, 5)
# (58, 6)
# Processing {} Rome, Italy-8-6
# BBox size 5999.999999999698m x 5997.4310678169295m. Search r=169.66930118699977m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# retry
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# retry
# 1850
# retry
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# retry
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 213 Unique Venues Scraped: 2019-10-03 23:47:56.114784.
# Maximum response size 6 venues.
# (213, 5)
# (40, 6)
# Processing {} Rome, Italy-8-7
# BBox size 5999.999999999698m x 5997.4310678169295m. Search r=169.66930118699977m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 40 Unique Venues Scraped: 2019-10-04 00:28:12.055183.
# Maximum response size 2 venues.
# (40, 5)
# (8, 6)
# Processing {} Rome, Italy-8-8
# BBox size 5999.999999999698m x 5997.4310678169295m. Search r=169.66930118699977m
# 50
# 100
# retry
# retry
# retry
# 150
# retry
# retry
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# retry
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# retry
# retry
# retry
# retry
# retry
# retry
# retry
# retry
# retry
# retry
# retry
# retry
# retry
# retry
# retry
# retry
# retry
# retry
# retry
# retry
# retry
# retry
# retry
# retry
# retry
# retry
# retry
# retry
# retry
