# %%
import yaml
import requests
import datetime
import time
import csv
import pandas as pd
import math

# Get all Venue IDs for venues within the bounding box.


def get_delta(lower, upper, length):
    return (upper - lower)/length


def getBBoxVenuesNWSE(bound_N,bound_W,bound_S,bound_E,divisions,
                 foursquare_id,foursquare_secret):    
    
    lat_delta = get_delta(bound_N,bound_S,divisions)
    long_delta = get_delta(bound_W,bound_E, divisions)
    
    dist_ns=110574*abs(bound_N-bound_S)
    dist_ew=111320*math.cos(math.radians(bound_N))*abs(bound_E-bound_W)
    
    
    search_params = {
        'client_id': foursquare_id,
        'client_secret': foursquare_secret,
  #      'intent': 'browse',
        'limit': 50,
        'v': '20181209',
        'radius' : math.sqrt(dist_ew*dist_ew+dist_ns*dist_ns)/divisions,
        'sortByDistance': 1
        
    }
    
    print('BBox size {}m x {}m. Search r={}m'.format(dist_ns,dist_ew,search_params['radius']))
    

    search_count = 0

    venues_list=[]
        
    max_response_size=0

    for lat in range(divisions):
        for long in range(divisions):
            
            ne_lat = bound_N + lat * lat_delta
            ne_long = bound_W+ (long+1) * long_delta
            
            #search_params.update({'ne': '{},{}'.format(ne_lat, ne_long),
            #                      'sw': '{},{}'.format(ne_lat - lat_delta,
            #                                           ne_long - long_delta)})                          
            
            search_params.update({'ll': '{},{}'.format(ne_lat-0.5*lat_delta, ne_long-0.5*long_delta)})
  
            items=[]
            
            # print(search_params)
            while True:
                try:
                    r = requests.get('https://api.foursquare.com/v2/venues/explore',
                                 params=search_params)
                except requests.exceptions.RequestException as e:  
                    print(e)    
                    print('Sleeping 10s')
                    time.sleep(10)


                try:
                    resp=r.json()['response']
                except:
                    time.sleep(5)
                    print('retry')
                    continue

                if 'groups' in resp:
                    break
                else:
                    time.sleep(5)
                    print('retry')

            #if 'venues' in r.json()['response']:
            #    venues = r.json()['response']['venues']
            items = r.json()['response']['groups'][0]['items']
            time.sleep(0.6)

            # print('Query returned {} items: {}'.format(len(items),items))
            
            for item in items:
                venue=item['venue']
                categories = venue.get('categories', '')
                if len(categories) == 0:
                   categories = ''
                else:
                    categories = ';'.join([x['name'] for x in categories])
               # print(categories)
                venues_list.append([venue['name'], 
                                    venue['id'],
                    venue['location']['lat'], 
                    venue['location']['lng'],  
                    categories]);

            #print('Search retrieved {} venues.'.format(len(items)))
            max_response_size=max(max_response_size,len(items))

            if len(items) >= search_params['limit']:
                print("Recursive split")
                return getBBoxVenuesNWSE(bound_N,bound_W,bound_S,bound_E,2*divisions,
                 foursquare_id,foursquare_secret) 

            search_count += 1
            if search_count % 50 == 0:
                print(search_count)
         
        # gets fussy when more than 5000 requests/hr
    #        if search_count % 5000 == 0:
    #           time.sleep(60*60)

            

    print('{} Unique Venues Scraped: {}.'.format(
        len(venues_list), datetime.datetime.now()))

    print('Maximum response size {} venues.'.format(max_response_size))
    return venues_list

#df=pd.DataFrame(venues_list)
#df.to_csv('tampere_venues.csv',index=False)
#df

def getCenteredVenues(lat,lng,dist_to_side,divisions,foursquare_id,foursquare_secret):

    # convert distance in meters to latitude/longtitude deltas    
    
    delta_lat=dist_to_side/110574
    delta_lng=dist_to_side/(111320*math.cos(math.radians(lat)))
    
    return getBBoxVenuesNWSE(lat+delta_lat,lng-delta_lng,lat-delta_lat,lng+delta_lng,divisions,
                 foursquare_id,foursquare_secret)

def scrapeNamedCity(city,df,foursquare_id,foursquare_secret):
    from geopy.geocoders import Nominatim

    geolocator = Nominatim(user_agent="my-application")

    while True:
        try:
            location = geolocator.geocode(city)
        except:
            time.sleep(3)
            continue
        else:
            break
            
    lat= location.latitude
    lng = location.longitude
    dist_to_side=3000# meters
    print('The geographical coordinates of {} city centre are {}, {}.'.format(city,lat,lng))
    
    # convert distance in meters to latitude/longtitude deltas    
    
    delta_lat=2*dist_to_side/110574
    delta_lng=2*dist_to_side/(111320*math.cos(math.radians(lat)))
    
    
    divisions=math.ceil(2*25*dist_to_side/3000)

    processed_cities = set()

    if len(df)>0:
        processed_cities=set(df['City'].unique())
  
    for step_lat in range(9):
        for step_long in range(9):
            
            lat_tile = lat + (step_lat-4) * delta_lat
            long_tile = lng + (step_long-4) * delta_lng
            
            city_string = '{}-{}-{}'.format(city,step_lat,step_long)
 
            if city_string in processed_cities:
                print('Skipping {}'.format(city_string))
            else:
                print('Processing {}', format(city_string))
                venues_list=getCenteredVenues(lat_tile,long_tile,dist_to_side,divisions,CLIENT_ID,CLIENT_SECRET)
                dfn=pd.DataFrame(venues_list)
                print(dfn.shape)
                dfn.drop_duplicates(inplace=True)
                dfn.columns=['Name','Id','Latitude','Longtitude','Categories']
                dfn['City']=city_string
        
                print(dfn.shape)
        
                if df.size > 0:
                   df=df.append(dfn,ignore_index=True)
                else:
                   df=dfn
            df.to_csv(FILENAME,index=False)
                        
    return df

# %%
import pandas as pd
import os
import math
import numpy as np # library to handle data in a vectorized manner
# !conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library

# !conda install -c conda-forge geopy --yes 
# uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import matplotlib.cm as cm
import matplotlib.colors as colors


print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Libraries imported.

# %%
CLIENT_ID = 'U1ND1RSESM34E0F5N2VX0WIY1TSNYQM41LXUBM523HOLJXCV' # your Foursquare ID
CLIENT_SECRET = 'X0KNHD5JZDI4XS0TJLWZPZ5AGC44KHUB4J0STYMT2R5MEKPV' # your Foursquare Secret

#kaisa 
CLIENT_ID='HPVS5YBLFPA0AQ1OZOM42KQQ4EHFRUVO1DZS00ENE0HPUI0A'
CLIENT_SECRET='250O40DSBBEP53FPSDEIDBVINQ3VZD4G5SHHHYHPEGIMRGDR'

FILENAME='scraped_venues_tiled.csv'

cities_list=[
    "London, England",
    "Berlin, Germany",
    "Rome, Italy"
]

#cities_list=[
#   "Cremona, Italy"
#]


cities_list_test=['Pori, Finland',"Lappeenranta, Finland"]

df=pd.DataFrame()
try:
    df=pd.read_csv(FILENAME)
except:
    pass

for city in cities_list:
        
    print('city {}'.format(city))
    df=scrapeNamedCity(city,df,CLIENT_ID,CLIENT_SECRET)
    print(df.shape)
    df.to_csv(FILENAME,index=False)
df
# Out:
# city London, England
# The geographical coordinates of London, England city centre are 51.5073219, -0.1276474.
# Skipping London, England-0-0
# Skipping London, England-0-1
# Skipping London, England-0-2
# Skipping London, England-0-3
# Skipping London, England-0-4
# Skipping London, England-0-5
# Skipping London, England-0-6
# Skipping London, England-0-7
# Skipping London, England-0-8
# Skipping London, England-1-0
# Skipping London, England-1-1
# Skipping London, England-1-2
# Skipping London, England-1-3
# Skipping London, England-1-4
# Skipping London, England-1-5
# Skipping London, England-1-6
# Skipping London, England-1-7
# Processing {} London, England-1-8
# BBox size 5999.999999999698m x 5996.4473160143725m. Search r=169.6553923855441m
# 50
# 100
# 150
# 200
# 250
# 300
# retry
# retry
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# retry
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 297 Unique Venues Scraped: 2019-09-24 08:36:06.236483.
# Maximum response size 6 venues.
# (297, 5)
# (53, 6)
# Processing {} London, England-2-0
# BBox size 5999.999999999698m x 5996.4404114980925m. Search r=169.6552947698878m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# retry
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# retry
# 900
# retry
# 950
# 1000
# 1050
# 1100
# 1150
# retry
# 1200
# retry
# 1250
# 1300
# 1350
# retry
# 1400
# 1450
# 1500
# 1550
# 1600
# retry
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1662 Unique Venues Scraped: 2019-09-24 09:21:12.313707.
# Maximum response size 26 venues.
# (1662, 5)
# (320, 6)
# Processing {} London, England-2-1
# BBox size 5999.999999999698m x 5996.4404114980925m. Search r=169.6552947698878m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# retry
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# retry
# 1700
# retry
# 1750
# 1800
# 1850
# 1900
# 1950
# retry
# retry
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1998 Unique Venues Scraped: 2019-09-24 10:07:17.897826.
# Maximum response size 25 venues.
# (1998, 5)
# (389, 6)
# Processing {} London, England-2-2
# BBox size 5999.999999999698m x 5996.4404114980925m. Search r=169.6552947698878m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# retry
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# retry
# 2450
# 2500
# 3713 Unique Venues Scraped: 2019-09-24 10:52:20.999672.
# Maximum response size 48 venues.
# (3713, 5)
# (712, 6)
# Processing {} London, England-2-3
# BBox size 5999.999999999698m x 5996.4404114980925m. Search r=169.6552947698878m
# 50
# 100
# 150
# 200
# 250
# Recursive split
# BBox size 5999.999999999698m x 5996.4404114980925m. Search r=84.8276473849439m
# retry
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# retry
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# retry
# 2900
# retry
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# retry
# 3250
# retry
# 3300
# retry
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800
# 3850
# 3900
# 3950
# 4000
# 4050
# 4100
# 4150
# 4200
# 4250
# 4300
# 4350
# 4400
# 4450
# 4500
# 4550
# 4600
# 4650
# 4700
# 4750
# 4800
# 4850
# 4900
# 4950
# 5000
# 5050
# 5100
# 5150
# 5200
# 5250
# 5300
# 5350
# retry
# 5400
# 5450
# 5500
# 5550
# 5600
# 5650
# retry
# 5700
# 5750
# 5800
# 5850
# 5900
# 5950
# 6000
# 6050
# 6100
# retry
# retry
# 6150
# 6200
# 6250
# 6300
# 6350
# 6400
# retry
# 6450
# 6500
# 6550
# 6600
# 6650
# 6700
# 6750
# retry
# retry
# 6800
# 6850
# 6900
# 6950
# 7000
# 7050
# 7100
# 7150
# 7200
# 7250
# 7300
# 7350
# 7400
# 7450
# 7500
# 7550
# 7600
# 7650
# 7700
# 7750
# 7800
# 7850
# 7900
# 7950
# 8000
# retry
# 8050
# 8100
# 8150
# 8200
# 8250
# 8300
# 8350
# 8400
# 8450
# 8500
# 8550
# 8600
# 8650
# 8700
# 8750
# 8800
# 8850
# 8900
# 8950
# 9000
# 9050
# 9100
# 9150
# 9200
# 9250
# 9300
# 9350
# retry
# 9400
# 9450
# 9500
# 9550
# 9600
# 9650
# retry
# retry
# 9700
# 9750
# 9800
# 9850
# 9900
# 9950
# retry
# 10000
# 4390 Unique Venues Scraped: 2019-09-24 14:05:08.797132.
# Maximum response size 21 venues.
# (4390, 5)
# (751, 6)
# Processing {} London, England-2-4
# BBox size 5999.999999999698m x 5996.440411498095m. Search r=169.65529476988783m
# retry
# 50
# retry
# 100
# 150
# 200
# 250
# retry
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# retry
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 3651 Unique Venues Scraped: 2019-09-24 14:52:19.294529.
# Maximum response size 29 venues.
# (3651, 5)
# (708, 6)
# Processing {} London, England-2-5
# BBox size 5999.999999999698m x 5996.440411498094m. Search r=169.6552947698878m
# retry
# 50
# 100
# 150
# 200
# 250
# retry
# retry
# 300
# retry
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# retry
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 3310 Unique Venues Scraped: 2019-09-24 15:39:37.556817.
# Maximum response size 29 venues.
# (3310, 5)
# (625, 6)
# Processing {} London, England-2-6
# BBox size 5999.999999999698m x 5996.440411498094m. Search r=169.6552947698878m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# retry
# retry
# 650
# 700
# 750
# 800
# 850
# retry
# 900
# 950
# retry
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# retry
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# retry
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2195 Unique Venues Scraped: 2019-09-24 16:24:52.813373.
# Maximum response size 29 venues.
# (2195, 5)
# (428, 6)
# Processing {} London, England-2-7
# BBox size 5999.999999999698m x 5996.440411498095m. Search r=169.65529476988783m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# retry
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# retry
# 1450
# 1500
# retry
# retry
# retry
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# retry
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1373 Unique Venues Scraped: 2019-09-24 17:07:52.091861.
# Maximum response size 17 venues.
# (1373, 5)
# (271, 6)
# Processing {} London, England-2-8
# BBox size 5999.999999999698m x 5996.440411498096m. Search r=169.65529476988783m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# retry
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# retry
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 436 Unique Venues Scraped: 2019-09-24 17:49:03.954673.
# Maximum response size 5 venues.
# (436, 5)
# (80, 6)
# Processing {} London, England-3-0
# BBox size 5999.999999999698m x 5996.433490580624m. Search r=169.65519692240883m
# 50
# retry
# 100
# retry
# 150
# 200
# 250
# 300
# 350
# 400
# Recursive split
# BBox size 5999.999999999698m x 5996.433490580624m. Search r=84.82759846120442m
# 50
# retry
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# retry
# 500
# retry
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# retry
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# retry
# 3700
# 3750
# retry
# 3800
# 3850
# 3900
# 3950
# 4000
# 4050
# 4100
# 4150
# 4200
# 4250
# 4300
# 4350
# 4400
# retry
# 4450
# 4500
# 4550
# 4600
# 4650
# 4700
# 4750
# 4800
# 4850
# 4900
# 4950
# 5000
# 5050
# 5100
# 5150
# 5200
# 5250
# 5300
# 5350
# 5400
# 5450
# 5500
# 5550
# 5600
# retry
# 5650
# 5700
# 5750
# 5800
# 5850
# 5900
# 5950
# 6000
# 6050
# 6100
# 6150
# 6200
# 6250
# 6300
# 6350
# 6400
# 6450
# 6500
# 6550
# 6600
# 6650
# 6700
# 6750
# 6800
# retry
# 6850
# retry
# 6900
# 6950
# 7000
# 7050
# 7100
# retry
# 7150
# retry
# 7200
# 7250
# 7300
# 7350
# 7400
# 7450
# 7500
# 7550
# 7600
# 7650
# 7700
# 7750
# 7800
# 7850
# 7900
# 7950
# 8000
# 8050
# 8100
# 8150
# 8200
# 8250
# 8300
# 8350
# 8400
# 8450
# 8500
# 8550
# 8600
# 8650
# 8700
# 8750
# 8800
# 8850
# 8900
# 8950
# 9000
# 9050
# 9100
# 9150
# 9200
# 9250
# 9300
# 9350
# 9400
# 9450
# 9500
# 9550
# 9600
# 9650
# 9700
# 9750
# 9800
# 9850
# 9900
# 9950
# 10000
# 3175 Unique Venues Scraped: 2019-09-24 20:44:49.092442.
# Maximum response size 27 venues.
# (3175, 5)
# (565, 6)
# Processing {} London, England-3-1
# BBox size 5999.999999999698m x 5996.43349058062m. Search r=169.6551969224088m
# 50
# 100
# 150
# 200
# 250
# 300
# retry
# retry
# 350
# retry
# 400
# 450
# retry
# 500
# 550
# 600
# 650
# retry
# 700
# retry
# retry
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# retry
# 1100
# retry
# 1150
# 1200
# 1250
# 1300
# 1350
# retry
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 3260 Unique Venues Scraped: 2019-09-24 21:29:15.754254.
# Maximum response size 21 venues.
# (3260, 5)
# (628, 6)
# Processing {} London, England-3-2
# BBox size 5999.999999999698m x 5996.43349058062m. Search r=169.6551969224088m
# 50
# 100
# 150
# 200
# 250
# 300
# retry
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# retry
# 1350
# retry
# 1400
# 1450
# 1500
# 1550
# 1600
# retry
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# retry
# retry
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# retry
# 2400
# 2450
# 2500
# 4401 Unique Venues Scraped: 2019-09-24 22:13:13.492144.
# Maximum response size 44 venues.
# (4401, 5)
# (835, 6)
# Processing {} London, England-3-3
# BBox size 5999.999999999698m x 5996.433490580622m. Search r=169.6551969224088m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# retry
# retry
# 2250
# retry
# 2300
# 2350
# 2400
# 2450
# 2500
# 6133 Unique Venues Scraped: 2019-09-24 22:55:59.370617.
# Maximum response size 33 venues.
# (6133, 5)
# (1196, 6)
# Processing {} London, England-3-4
# BBox size 5999.999999999698m x 5996.433490580624m. Search r=169.65519692240883m
# 50
# retry
# 100
# retry
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# retry
# 500
# retry
# 550
# 600
# 650
# 700
# 750
# 800
# Recursive split
# BBox size 5999.999999999698m x 5996.433490580624m. Search r=84.82759846120442m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# retry
# 1050
# retry
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# retry
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# retry
# 2950
# 3000
# 3050
# 3100
# 3150
# retry
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# retry
# 3650
# 3700
# 3750
# 3800
# 3850
# 3900
# 3950
# 4000
# 4050
# 4100
# 4150
# 4200
# 4250
# 4300
# 4350
# 4400
# 4450
# 4500
# 4550
# 4600
# 4650
# 4700
# 4750
# 4800
# 4850
# 4900
# 4950
# 5000
# 5050
# 5100
# 5150
# 5200
# 5250
# 5300
# 5350
# 5400
# 5450
# 5500
# 5550
# 5600
# 5650
# 5700
# 5750
# 5800
# 5850
# 5900
# retry
# retry
# retry
# 5950
# retry
# 6000
# 6050
# 6100
# 6150
# 6200
# 6250
# retry
# retry
# 6300
# 6350
# 6400
# 6450
# 6500
# 6550
# 6600
# 6650
# 6700
# 6750
# 6800
# 6850
# 6900
# 6950
# 7000
# 7050
# 7100
# 7150
# 7200
# 7250
# 7300
# 7350
# 7400
# 7450
# 7500
# 7550
# 7600
# 7650
# 7700
# 7750
# 7800
# 7850
# 7900
# 7950
# 8000
# 8050
# 8100
# 8150
# 8200
# 8250
# 8300
# 8350
# 8400
# 8450
# 8500
# 8550
# 8600
# 8650
# 8700
# 8750
# 8800
# 8850
# 8900
# 8950
# 9000
# 9050
# 9100
# 9150
# 9200
# 9250
# 9300
# 9350
# 9400
# 9450
# retry
# retry
# 9500
# retry
# 9550
# 9600
# 9650
# 9700
# 9750
# 9800
# 9850
# retry
# 9900
# 9950
# 10000
# 8979 Unique Venues Scraped: 2019-09-25 02:00:30.730685.
# Maximum response size 34 venues.
# (8979, 5)
# (1597, 6)
# Processing {} London, England-3-5
# BBox size 5999.999999999698m x 5996.433490580624m. Search r=169.65519692240883m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# retry
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 6102 Unique Venues Scraped: 2019-09-25 02:41:58.910972.
# Maximum response size 38 venues.
# (6102, 5)
# (1165, 6)
# Processing {} London, England-3-6
# BBox size 5999.999999999698m x 5996.433490580624m. Search r=169.65519692240883m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# retry
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# retry
# retry
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2799 Unique Venues Scraped: 2019-09-25 03:24:28.834331.
# Maximum response size 28 venues.
# (2799, 5)
# (537, 6)
# Processing {} London, England-3-7
# BBox size 5999.999999999698m x 5996.433490580624m. Search r=169.65519692240883m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# retry
# 1600
# retry
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# retry
# 2000
# retry
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# retry
# 2400
# 2450
# 2500
# 2128 Unique Venues Scraped: 2019-09-25 04:06:58.329585.
# Maximum response size 17 venues.
# (2128, 5)
# (411, 6)
# Processing {} London, England-3-8
# BBox size 5999.999999999698m x 5996.433490580624m. Search r=169.65519692240883m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# retry
# 2050
# 2100
# retry
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1485 Unique Venues Scraped: 2019-09-25 04:47:37.357538.
# Maximum response size 14 venues.
# (1485, 5)
# (259, 6)
# Processing {} London, England-4-0
# BBox size 5999.999999999698m x 5996.426553190994m. Search r=169.65509884210422m
# retry
# 50
# retry
# 100
# 150
# 200
# 250
# retry
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# retry
# 750
# 800
# 850
# retry
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# retry
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2062 Unique Venues Scraped: 2019-09-25 05:28:44.584387.
# Maximum response size 15 venues.
# (2062, 5)
# (411, 6)
# Processing {} London, England-4-1
# BBox size 5999.999999999698m x 5996.4265531909905m. Search r=169.6550988421042m
# 50
# retry
# retry
# retry
# retry
# 100
# retry
# 150
# 200
# 250
# 300
# 350
# 400
# retry
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2459 Unique Venues Scraped: 2019-09-25 06:11:23.131041.
# Maximum response size 15 venues.
# (2459, 5)
# (460, 6)
# Processing {} London, England-4-2
# BBox size 5999.999999999698m x 5996.4265531909905m. Search r=169.6550988421042m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# retry
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# retry
# retry
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 5912 Unique Venues Scraped: 2019-09-25 06:54:09.700170.
# Maximum response size 43 venues.
# (5912, 5)
# (1110, 6)
# Processing {} London, England-4-3
# BBox size 5999.999999999698m x 5996.4265531909905m. Search r=169.6550988421042m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# Recursive split
# BBox size 5999.999999999698m x 5996.4265531909905m. Search r=84.8275494210521m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# retry
# 1350
# retry
# 1400
# 1450
# 1500
# 1550
# 1600
# retry
# 1650
# retry
# retry
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800
# 3850
# 3900
# 3950
# 4000
# 4050
# 4100
# 4150
# 4200
# 4250
# 4300
# 4350
# 4400
# 4450
# 4500
# 4550
# 4600
# 4650
# 4700
# 4750
# 4800
# 4850
# 4900
# retry
# 4950
# 5000
# 5050
# 5100
# 5150
# 5200
# retry
# retry
# 5250
# 5300
# 5350
# 5400
# 5450
# 5500
# 5550
# 5600
# 5650
# 5700
# 5750
# 5800
# 5850
# 5900
# 5950
# 6000
# 6050
# 6100
# 6150
# 6200
# 6250
# 6300
# 6350
# 6400
# 6450
# 6500
# 6550
# 6600
# 6650
# 6700
# 6750
# 6800
# 6850
# 6900
# 6950
# 7000
# 7050
# 7100
# 7150
# 7200
# 7250
# 7300
# 7350
# 7400
# 7450
# 7500
# 7550
# 7600
# 7650
# 7700
# 7750
# 7800
# 7850
# 7900
# 7950
# 8000
# 8050
# 8100
# 8150
# 8200
# 8250
# 8300
# 8350
# 8400
# retry
# retry
# 8450
# 8500
# 8550
# 8600
# 8650
# 8700
# retry
# retry
# 8750
# 8800
# 8850
# 8900
# 8950
# 9000
# 9050
# 9100
# 9150
# 9200
# 9250
# 9300
# 9350
# 9400
# 9450
# 9500
# 9550
# 9600
# 9650
# 9700
# 9750
# 9800
# 9850
# 9900
# 9950
# 10000
# 15540 Unique Venues Scraped: 2019-09-25 09:57:45.023592.
# Maximum response size 38 venues.
# (15540, 5)
# (2729, 6)
# Processing {} London, England-4-4
# BBox size 5999.999999999698m x 5996.426553190993m. Search r=169.65509884210422m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# retry
# 850
# 900
# Recursive split
# BBox size 5999.999999999698m x 5996.426553190993m. Search r=84.82754942105211m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# retry
# retry
# retry
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# retry
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# retry
# 3700
# 3750
# 3800
# 3850
# 3900
# 3950
# 4000
# 4050
# 4100
# 4150
# 4200
# 4250
# 4300
# 4350
# 4400
# 4450
# retry
# retry
# 4500
# retry
# 4550
# 4600
# 4650
# 4700
# 4750
# retry
# 4800
# retry
# 4850
# 4900
# 4950
# 5000
# 5050
# 5100
# 5150
# 5200
# 5250
# 5300
# 5350
# 5400
# 5450
# 5500
# 5550
# 5600
# 5650
# 5700
# 5750
# 5800
# 5850
# 5900
# 5950
# 6000
# 6050
# 6100
# 6150
# 6200
# 6250
# 6300
# 6350
# 6400
# 6450
# 6500
# 6550
# 6600
# 6650
# 6700
# 6750
# 6800
# 6850
# 6900
# 6950
# 7000
# 7050
# 7100
# 7150
# 7200
# 7250
# 7300
# 7350
# 7400
# 7450
# 7500
# 7550
# 7600
# 7650
# 7700
# 7750
# 7800
# 7850
# 7900
# 7950
# 8000
# retry
# 8050
# retry
# 8100
# retry
# 8150
# 8200
# 8250
# 8300
# retry
# 8350
# 8400
# 8450
# retry
# 8500
# 8550
# 8600
# 8650
# 8700
# 8750
# 8800
# 8850
# 8900
# 8950
# 9000
# 9050
# 9100
# 9150
# 9200
# 9250
# 9300
# 9350
# 9400
# 9450
# 9500
# 9550
# 9600
# 9650
# 9700
# 9750
# 9800
# 9850
# 9900
# 9950
# 10000
# 33182 Unique Venues Scraped: 2019-09-25 13:04:27.852324.
# Maximum response size 42 venues.
# (33182, 5)
# (5652, 6)
# Processing {} London, England-4-5
# BBox size 5999.999999999698m x 5996.426553190992m. Search r=169.65509884210422m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# Recursive split
# BBox size 5999.999999999698m x 5996.426553190992m. Search r=84.82754942105211m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# retry
# retry
# retry
# 1150
# retry
# 1200
# 1250
# 1300
# 1350
# 1400
# retry
# 1450
# 1500
# retry
# retry
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800
# 3850
# 3900
# 3950
# 4000
# 4050
# 4100
# 4150
# 4200
# 4250
# 4300
# 4350
# 4400
# 4450
# 4500
# 4550
# 4600
# 4650
# retry
# 4700
# 4750
# 4800
# 4850
# 4900
# 4950
# retry
# retry
# retry
# 5000
# 5050
# 5100
# 5150
# 5200
# 5250
# 5300
# 5350
# 5400
# 5450
# 5500
# 5550
# 5600
# 5650
# 5700
# 5750
# 5800
# 5850
# 5900
# 5950
# 6000
# 6050
# 6100
# 6150
# 6200
# 6250
# 6300
# 6350
# 6400
# 6450
# 6500
# 6550
# 6600
# 6650
# 6700
# 6750
# 6800
# 6850
# 6900
# 6950
# 7000
# 7050
# 7100
# 7150
# 7200
# 7250
# 7300
# 7350
# 7400
# 7450
# 7500
# 7550
# 7600
# 7650
# 7700
# 7750
# 7800
# 7850
# 7900
# 7950
# 8000
# 8050
# 8100
# retry
# 8150
# retry
# 8200
# 8250
# 8300
# 8350
# 8400
# 8450
# retry
# 8500
# 8550
# 8600
# 8650
# 8700
# 8750
# 8800
# 8850
# 8900
# 8950
# 9000
# 9050
# 9100
# 9150
# 9200
# 9250
# 9300
# 9350
# 9400
# 9450
# 9500
# 9550
# 9600
# 9650
# 9700
# 9750
# 9800
# 9850
# 9900
# 9950
# 10000
# 14095 Unique Venues Scraped: 2019-09-25 16:01:24.165233.
# Maximum response size 22 venues.
# (14095, 5)
# (2469, 6)
# Processing {} London, England-4-6
# BBox size 5999.999999999698m x 5996.426553190992m. Search r=169.65509884210422m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# retry
# 1850
# 1900
# 1950
# 2000
# 2050
# retry
# retry
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 4874 Unique Venues Scraped: 2019-09-25 16:43:57.256232.
# Maximum response size 31 venues.
# (4874, 5)
# (939, 6)
# Processing {} London, England-4-7
# BBox size 5999.999999999698m x 5996.426553190993m. Search r=169.65509884210422m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# retry
# 1850
# 1900
# 1950
# 2000
# retry
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1272 Unique Venues Scraped: 2019-09-25 17:25:06.653340.
# Maximum response size 7 venues.
# (1272, 5)
# (240, 6)
# Processing {} London, England-4-8
# BBox size 5999.999999999698m x 5996.426553190994m. Search r=169.65509884210422m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# retry
# retry
# 400
# 450
# 500
# 550
# 600
# retry
# retry
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# retry
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 797 Unique Venues Scraped: 2019-09-25 18:07:28.281551.
# Maximum response size 10 venues.
# (797, 5)
# (151, 6)
# Processing {} London, England-5-0
# BBox size 5999.999999999698m x 5996.419599257836m. Search r=169.65500052796543m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# retry
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# retry
# retry
# retry
# retry
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1758 Unique Venues Scraped: 2019-09-25 18:49:49.829375.
# Maximum response size 40 venues.
# (1758, 5)
# (316, 6)
# Processing {} London, England-5-1
# BBox size 5999.999999999698m x 5996.41959925784m. Search r=169.65500052796548m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# retry
# 2500
# 2306 Unique Venues Scraped: 2019-09-25 19:30:53.206981.
# Maximum response size 14 venues.
# (2306, 5)
# (441, 6)
# Processing {} London, England-5-2
# BBox size 5999.999999999698m x 5996.41959925784m. Search r=169.65500052796548m
# retry
# 50
# 100
# 150
# 200
# 250
# retry
# 300
# retry
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 3677 Unique Venues Scraped: 2019-09-25 20:13:25.204566.
# Maximum response size 40 venues.
# (3677, 5)
# (697, 6)
# Processing {} London, England-5-3
# BBox size 5999.999999999698m x 5996.419599257838m. Search r=169.65500052796546m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# retry
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# retry
# 1000
# retry
# retry
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# retry
# retry
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# retry
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 5981 Unique Venues Scraped: 2019-09-25 20:57:04.650886.
# Maximum response size 47 venues.
# (5981, 5)
# (1149, 6)
# Processing {} London, England-5-4
# BBox size 5999.999999999698m x 5996.419599257836m. Search r=169.65500052796543m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# retry
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# retry
# 1950
# retry
# retry
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# retry
# 2300
# 2350
# 2400
# 2450
# 2500
# 10320 Unique Venues Scraped: 2019-09-25 21:40:50.267267.
# Maximum response size 47 venues.
# (10320, 5)
# (1981, 6)
# Processing {} London, England-5-5
# BBox size 5999.999999999698m x 5996.419599257836m. Search r=169.65500052796543m
# 50
# retry
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# Recursive split
# BBox size 5999.999999999698m x 5996.419599257836m. Search r=84.82750026398271m
# retry
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# retry
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# retry
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800
# 3850
# 3900
# 3950
# 4000
# 4050
# 4100
# 4150
# 4200
# 4250
# 4300
# 4350
# 4400
# retry
# 4450
# 4500
# 4550
# 4600
# 4650
# 4700
# retry
# 4750
# 4800
# 4850
# 4900
# 4950
# 5000
# 5050
# 5100
# 5150
# 5200
# 5250
# 5300
# 5350
# 5400
# 5450
# 5500
# 5550
# 5600
# 5650
# 5700
# 5750
# 5800
# 5850
# 5900
# 5950
# 6000
# 6050
# 6100
# 6150
# 6200
# retry
# 6250
# 6300
# 6350
# 6400
# 6450
# 6500
# 6550
# 6600
# retry
# 6650
# 6700
# 6750
# 6800
# 6850
# 6900
# 6950
# 7000
# 7050
# 7100
# 7150
# 7200
# 7250
# 7300
# 7350
# 7400
# 7450
# 7500
# 7550
# 7600
# 7650
# 7700
# 7750
# 7800
# 7850
# 7900
# retry
# 7950
# retry
# retry
# retry
# 8000
# 8050
# 8100
# 8150
# 8200
# 8250
# retry
# 8300
# 8350
# 8400
# 8450
# 8500
# 8550
# 8600
# 8650
# 8700
# 8750
# 8800
# 8850
# 8900
# 8950
# 9000
# 9050
# 9100
# 9150
# 9200
# 9250
# 9300
# 9350
# 9400
# 9450
# 9500
# 9550
# 9600
# 9650
# 9700
# 9750
# 9800
# 9850
# 9900
# 9950
# 10000
# 9340 Unique Venues Scraped: 2019-09-26 01:05:34.039552.
# Maximum response size 30 venues.
# (9340, 5)
# (1664, 6)
# Processing {} London, England-5-6
# BBox size 5999.999999999698m x 5996.419599257836m. Search r=169.65500052796543m
# 50
# 100
# retry
# 150
# 200
# 250
# 300
# 350
# 400
# retry
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# retry
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# retry
# 1500
# retry
# 1550
# 1600
# retry
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 3629 Unique Venues Scraped: 2019-09-26 01:48:50.206589.
# Maximum response size 22 venues.
# (3629, 5)
# (683, 6)
# Processing {} London, England-5-7
# BBox size 5999.999999999698m x 5996.419599257836m. Search r=169.65500052796543m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1714 Unique Venues Scraped: 2019-09-26 02:29:22.080184.
# Maximum response size 7 venues.
# (1714, 5)
# (334, 6)
# Processing {} London, England-5-8
# BBox size 5999.999999999698m x 5996.419599257836m. Search r=169.65500052796543m
# 50
# retry
# retry
# retry
# 100
# 150
# 200
# 250
# 300
# 350
# retry
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2058 Unique Venues Scraped: 2019-09-26 03:11:23.850024.
# Maximum response size 35 venues.
# (2058, 5)
# (367, 6)
# Processing {} London, England-6-0
# BBox size 5999.999999999698m x 5996.412628709386m. Search r=169.65490197897827m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# retry
# 1200
# retry
# 1250
# 1300
# 1350
# retry
# 1400
# 1450
# retry
# retry
# 1500
# 1550
# 1600
# 1650
# 1700
# retry
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1004 Unique Venues Scraped: 2019-09-26 03:53:39.998977.
# Maximum response size 15 venues.
# (1004, 5)
# (179, 6)
# Processing {} London, England-6-1
# BBox size 5999.999999999698m x 5996.412628709386m. Search r=169.65490197897827m
# 50
# retry
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# retry
# 2300
# 2350
# 2400
# 2450
# 2500
# 1439 Unique Venues Scraped: 2019-09-26 04:35:18.905047.
# Maximum response size 18 venues.
# (1439, 5)
# (276, 6)
# Processing {} London, England-6-2
# BBox size 5999.999999999698m x 5996.412628709386m. Search r=169.65490197897827m
# 50
# retry
# retry
# retry
# 100
# 150
# 200
# 250
# 300
# 350
# retry
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2117 Unique Venues Scraped: 2019-09-26 05:17:08.164966.
# Maximum response size 14 venues.
# (2117, 5)
# (400, 6)
# Processing {} London, England-6-3
# BBox size 5999.999999999698m x 5996.412628709392m. Search r=169.6549019789783m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# retry
# retry
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# retry
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2452 Unique Venues Scraped: 2019-09-26 05:59:24.809210.
# Maximum response size 24 venues.
# (2452, 5)
# (453, 6)
# Processing {} London, England-6-4
# BBox size 5999.999999999698m x 5996.41262870939m. Search r=169.6549019789783m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# retry
# retry
# 1950
# 2000
# 2050
# 2100
# 2150
# retry
# retry
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 3867 Unique Venues Scraped: 2019-09-26 06:42:12.924733.
# Maximum response size 28 venues.
# (3867, 5)
# (748, 6)
# Processing {} London, England-6-5
# BBox size 5999.999999999698m x 5996.41262870939m. Search r=169.6549019789783m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2870 Unique Venues Scraped: 2019-09-26 07:22:57.694968.
# Maximum response size 10 venues.
# (2870, 5)
# (563, 6)
# Processing {} London, England-6-6
# BBox size 5999.999999999698m x 5996.41262870939m. Search r=169.6549019789783m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# retry
# 550
# 600
# 650
# 700
# 750
# retry
# 800
# retry
# 850
# 900
# 950
# 1000
# 1050
# 1100
# retry
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1772 Unique Venues Scraped: 2019-09-26 08:04:56.909137.
# Maximum response size 19 venues.
# (1772, 5)
# (345, 6)
# Processing {} London, England-6-7
# BBox size 5999.999999999698m x 5996.41262870939m. Search r=169.6549019789783m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# retry
# retry
# retry
# retry
# 1600
# 1650
# 1700
# 1750
# 1800
# retry
# 1850
# retry
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 815 Unique Venues Scraped: 2019-09-26 08:47:39.994906.
# Maximum response size 6 venues.
# (815, 5)
# (154, 6)
# Processing {} London, England-6-8
# BBox size 5999.999999999698m x 5996.41262870939m. Search r=169.6549019789783m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 670 Unique Venues Scraped: 2019-09-26 09:28:05.810751.
# Maximum response size 6 venues.
# (670, 5)
# (117, 6)
# Processing {} London, England-7-0
# BBox size 5999.999999999698m x 5996.405641473479m. Search r=169.6548031941228m
# 50
# 100
# retry
# 150
# retry
# retry
# retry
# 200
# 250
# 300
# 350
# 400
# retry
# retry
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# retry
# 800
# retry
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 688 Unique Venues Scraped: 2019-09-26 10:10:59.332047.
# Maximum response size 7 venues.
# (688, 5)
# (123, 6)
# Processing {} London, England-7-1
# BBox size 5999.999999999698m x 5996.405641473482m. Search r=169.65480319412282m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# retry
# 1200
# retry
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# retry
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2571 Unique Venues Scraped: 2019-09-26 10:52:58.177566.
# Maximum response size 37 venues.
# (2571, 5)
# (481, 6)
# Processing {} London, England-7-2
# BBox size 5999.999999999698m x 5996.405641473482m. Search r=169.65480319412282m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# retry
# retry
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# retry
# 2300
# retry
# retry
# 2350
# 2400
# 2450
# 2500
# 1011 Unique Venues Scraped: 2019-09-26 11:34:53.846874.
# Maximum response size 15 venues.
# (1011, 5)
# (188, 6)
# Processing {} London, England-7-3
# BBox size 5999.999999999698m x 5996.405641473482m. Search r=169.65480319412282m
# 50
# 100
# 150
# 200
# 250
# 300
# retry
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1180 Unique Venues Scraped: 2019-09-26 12:15:39.961408.
# Maximum response size 14 venues.
# (1180, 5)
# (223, 6)
# Processing {} London, England-7-4
# BBox size 5999.999999999698m x 5996.40564147348m. Search r=169.6548031941228m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# retry
# 950
# retry
# 1000
# 1050
# 1100
# 1150
# 1200
# retry
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# retry
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1194 Unique Venues Scraped: 2019-09-26 12:57:54.207090.
# Maximum response size 19 venues.
# (1194, 5)
# (242, 6)
# Processing {} London, England-7-5
# BBox size 5999.999999999698m x 5996.4056414734805m. Search r=169.6548031941228m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# retry
# 2000
# retry
# retry
# 2050
# 2100
# 2150
# 2200
# 2250
# retry
# 2300
# 2350
# 2400
# 2450
# 2500
# 2310 Unique Venues Scraped: 2019-09-26 13:40:18.809524.
# Maximum response size 41 venues.
# (2310, 5)
# (424, 6)
# Processing {} London, England-7-6
# BBox size 5999.999999999698m x 5996.4056414734805m. Search r=169.6548031941228m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# retry
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 861 Unique Venues Scraped: 2019-09-26 14:20:45.354098.
# Maximum response size 10 venues.
# (861, 5)
# (171, 6)
# Processing {} London, England-7-7
# BBox size 5999.999999999698m x 5996.40564147348m. Search r=169.6548031941228m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# retry
# 650
# 700
# 750
# 800
# 850
# 900
# retry
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 424 Unique Venues Scraped: 2019-09-26 15:02:07.957061.
# Maximum response size 6 venues.
# (424, 5)
# (78, 6)
# Processing {} London, England-7-8
# BBox size 5999.999999999698m x 5996.405641473479m. Search r=169.6548031941228m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# retry
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# retry
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 126 Unique Venues Scraped: 2019-09-26 15:43:51.946749.
# Maximum response size 4 venues.
# (126, 5)
# (21, 6)
# Processing {} London, England-8-0
# BBox size 5999.999999999698m x 5996.39863747754m. Search r=169.65470417237347m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1319 Unique Venues Scraped: 2019-09-26 16:24:29.221763.
# Maximum response size 19 venues.
# (1319, 5)
# (235, 6)
# Processing {} London, England-8-1
# BBox size 5999.999999999698m x 5996.39863747754m. Search r=169.65470417237347m
# 50
# 100
# 150
# 200
# 250
# 300
# retry
# 350
# retry
# 400
# 450
# 500
# 550
# 600
# 650
# retry
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 682 Unique Venues Scraped: 2019-09-26 17:06:42.853754.
# Maximum response size 5 venues.
# (682, 5)
# (136, 6)
# Processing {} London, England-8-2
# BBox size 5999.999999999698m x 5996.39863747754m. Search r=169.65470417237347m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# retry
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# retry
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# retry
# retry
# 1800
# 1850
# 1900
# retry
# 1950
# 2000
# retry
# 2050
# retry
# 2100
# retry
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1619 Unique Venues Scraped: 2019-09-26 17:49:05.135614.
# Maximum response size 38 venues.
# (1619, 5)
# (320, 6)
# Processing {} London, England-8-3
# BBox size 5999.999999999698m x 5996.398637477535m. Search r=169.65470417237339m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# retry
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 576 Unique Venues Scraped: 2019-09-26 18:29:52.317618.
# Maximum response size 6 venues.
# (576, 5)
# (108, 6)
# Processing {} London, England-8-4
# BBox size 5999.999999999698m x 5996.398637477537m. Search r=169.6547041723734m
# retry
# 50
# retry
# 100
# 150
# 200
# 250
# 300
# retry
# retry
# retry
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# retry
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 296 Unique Venues Scraped: 2019-09-26 19:12:06.663920.
# Maximum response size 6 venues.
# (296, 5)
# (57, 6)
# Processing {} London, England-8-5
# BBox size 5999.999999999698m x 5996.398637477537m. Search r=169.6547041723734m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# retry
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# retry
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# retry
# 1450
# retry
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1050 Unique Venues Scraped: 2019-09-26 19:54:23.365705.
# Maximum response size 12 venues.
# (1050, 5)
# (188, 6)
# Processing {} London, England-8-6
# BBox size 5999.999999999698m x 5996.398637477537m. Search r=169.6547041723734m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# retry
# 2350
# 2400
# 2450
# 2500
# 317 Unique Venues Scraped: 2019-09-26 20:35:20.925944.
# Maximum response size 4 venues.
# (317, 5)
# (61, 6)
# Processing {} London, England-8-7
# BBox size 5999.999999999698m x 5996.398637477537m. Search r=169.6547041723734m
# 50
# retry
# 100
# retry
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# retry
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# retry
# 2400
# 2450
# 2500
# 469 Unique Venues Scraped: 2019-09-26 21:15:49.367833.
# Maximum response size 9 venues.
# (469, 5)
# (97, 6)
# Processing {} London, England-8-8
# BBox size 5999.999999999698m x 5996.398637477537m. Search r=169.6547041723734m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# retry
# 900
# retry
# retry
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# retry
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# retry
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 268 Unique Venues Scraped: 2019-09-26 21:57:18.147098.
# Maximum response size 4 venues.
# (268, 5)
# (47, 6)
# (42679, 6)
# city Berlin, Germany
# The geographical coordinates of Berlin, Germany city centre are 52.5170365, 13.3888599.
# Processing {} Berlin, Germany-0-0
# BBox size 5999.999999999698m x 5996.323287830251m. Search r=169.65363889073734m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# retry
# 2100
# retry
# 2150
# retry
# 2200
# 2250
# 2300
# 2350
# retry
# retry
# retry
# 2400
# 2450
# 2500
# 312 Unique Venues Scraped: 2019-09-26 22:39:12.160209.
# Maximum response size 4 venues.
# (312, 5)
# (53, 6)
# Processing {} Berlin, Germany-0-1
# BBox size 5999.999999999698m x 5996.323287830251m. Search r=169.65363889073734m
# 50
# 100
# 150
# 200
# retry
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 135 Unique Venues Scraped: 2019-09-26 23:19:31.118828.
# Maximum response size 3 venues.
# (135, 5)
# (25, 6)
# Processing {} Berlin, Germany-0-2
# BBox size 5999.999999999698m x 5996.323287830251m. Search r=169.65363889073734m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# retry
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 236 Unique Venues Scraped: 2019-09-27 00:00:56.136583.
# Maximum response size 5 venues.
# (236, 5)
# (44, 6)
# Processing {} Berlin, Germany-0-3
# BBox size 5999.999999999698m x 5996.323287830251m. Search r=169.65363889073734m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# retry
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# retry
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# retry
# 1800
# retry
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# retry
# 2150
# retry
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# retry
# 2500
# 332 Unique Venues Scraped: 2019-09-27 00:43:32.725340.
# Maximum response size 4 venues.
# (332, 5)
# (60, 6)
# Processing {} Berlin, Germany-0-4
# BBox size 5999.999999999698m x 5996.323287830251m. Search r=169.65363889073734m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 229 Unique Venues Scraped: 2019-09-27 01:23:36.697434.
# Maximum response size 4 venues.
# (229, 5)
# (42, 6)
# Processing {} Berlin, Germany-0-5
# BBox size 5999.999999999698m x 5996.323287830251m. Search r=169.65363889073734m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# retry
# retry
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 293 Unique Venues Scraped: 2019-09-27 02:05:07.432105.
# Maximum response size 10 venues.
# (293, 5)
# (51, 6)
# Processing {} Berlin, Germany-0-6
# BBox size 5999.999999999698m x 5996.323287830251m. Search r=169.65363889073734m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# retry
# retry
# retry
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# retry
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 267 Unique Venues Scraped: 2019-09-27 02:47:01.778610.
# Maximum response size 14 venues.
# (267, 5)
# (54, 6)
# Processing {} Berlin, Germany-0-7
# BBox size 5999.999999999698m x 5996.323287830251m. Search r=169.65363889073734m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# retry
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 749 Unique Venues Scraped: 2019-09-27 03:27:03.569514.
# Maximum response size 7 venues.
# (749, 5)
# (142, 6)
# Processing {} Berlin, Germany-0-8
# BBox size 5999.999999999698m x 5996.323287830251m. Search r=169.65363889073734m
# 50
# 100
# 150
# retry
# 200
# retry
# retry
# 250
# 300
# 350
# 400
# 450
# 500
# retry
# retry
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# retry
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 168 Unique Venues Scraped: 2019-09-27 04:08:41.688369.
# Maximum response size 3 venues.
# (168, 5)
# (27, 6)
# Processing {} Berlin, Germany-1-0
# BBox size 5999.999999999698m x 5996.316083834148m. Search r=169.65353704210764m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# retry
# retry
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# retry
# retry
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 443 Unique Venues Scraped: 2019-09-27 04:49:57.858140.
# Maximum response size 5 venues.
# (443, 5)
# (79, 6)
# Processing {} Berlin, Germany-1-1
# BBox size 5999.999999999698m x 5996.316083834148m. Search r=169.65353704210764m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# retry
# 2500
# 737 Unique Venues Scraped: 2019-09-27 05:30:14.657887.
# Maximum response size 11 venues.
# (737, 5)
# (136, 6)
# Processing {} Berlin, Germany-1-2
# BBox size 5999.999999999698m x 5996.316083834148m. Search r=169.65353704210764m
# retry
# retry
# 50
# 100
# 150
# 200
# 250
# 300
# retry
# 350
# 400
# 450
# 500
# 550
# retry
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 201 Unique Venues Scraped: 2019-09-27 06:11:18.207181.
# Maximum response size 3 venues.
# (201, 5)
# (36, 6)
# Processing {} Berlin, Germany-1-3
# BBox size 5999.999999999698m x 5996.316083834148m. Search r=169.65353704210764m
# 50
# 100
# 150
# 200
# 250
# 300
# retry
# 350
# 400
# 450
# 500
# 550
# 600
# retry
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# retry
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# retry
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 245 Unique Venues Scraped: 2019-09-27 06:52:35.546322.
# Maximum response size 6 venues.
# (245, 5)
# (45, 6)
# Processing {} Berlin, Germany-1-4
# BBox size 5999.999999999698m x 5996.316083834148m. Search r=169.65353704210764m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# retry
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# retry
# 2350
# 2400
# 2450
# 2500
# 535 Unique Venues Scraped: 2019-09-27 07:33:42.291667.
# Maximum response size 10 venues.
# (535, 5)
# (104, 6)
# Processing {} Berlin, Germany-1-5
# BBox size 5999.999999999698m x 5996.316083834148m. Search r=169.65353704210764m
# 50
# 100
# 150
# retry
# retry
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 377 Unique Venues Scraped: 2019-09-27 08:14:38.886216.
# Maximum response size 7 venues.
# (377, 5)
# (68, 6)
# Processing {} Berlin, Germany-1-6
# BBox size 5999.999999999698m x 5996.316083834148m. Search r=169.65353704210764m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# retry
# retry
# 1050
# 1100
# 1150
# 1200
# 1250
# retry
# retry
# 1300
# retry
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 447 Unique Venues Scraped: 2019-09-27 08:56:43.493152.
# Maximum response size 7 venues.
# (447, 5)
# (80, 6)
# Processing {} Berlin, Germany-1-7
# BBox size 5999.999999999698m x 5996.316083834148m. Search r=169.65353704210764m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# retry
# 2100
# retry
# retry
# 2150
# 2200
# 2250
# 2300
# 2350
# retry
# 2400
# 2450
# 2500
# 657 Unique Venues Scraped: 2019-09-27 09:38:42.461631.
# Maximum response size 5 venues.
# (657, 5)
# (115, 6)
# Processing {} Berlin, Germany-1-8
# BBox size 5999.999999999698m x 5996.316083834148m. Search r=169.65353704210764m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 27 Unique Venues Scraped: 2019-09-27 10:19:07.867256.
# Maximum response size 1 venues.
# (27, 5)
# (6, 6)
# Processing {} Berlin, Germany-2-0
# BBox size 5999.999999999698m x 5996.3088621267125m. Search r=169.65343494314016m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# retry
# 700
# retry
# 750
# 800
# 850
# 900
# 950
# 1000
# retry
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2840 Unique Venues Scraped: 2019-09-27 11:01:30.078474.
# Maximum response size 31 venues.
# (2840, 5)
# (502, 6)
# Processing {} Berlin, Germany-2-1
# BBox size 5999.999999999698m x 5996.3088621267125m. Search r=169.65343494314016m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# retry
# retry
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# retry
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1466 Unique Venues Scraped: 2019-09-27 11:44:01.425020.
# Maximum response size 13 venues.
# (1466, 5)
# (268, 6)
# Processing {} Berlin, Germany-2-2
# BBox size 5999.999999999698m x 5996.3088621267125m. Search r=169.65343494314016m
# 50
# 100
# 150
# 200
# 250
# 300

# %%
df
