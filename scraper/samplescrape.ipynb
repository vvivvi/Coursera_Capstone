# %%
import yaml
import requests
import datetime
import time
import csv
import pandas as pd
import math

# Get all Venue IDs for venues within the bounding box.


def get_delta(lower, upper, length):
    return (upper - lower)/length


def getBBoxVenuesNWSE(bound_N,bound_W,bound_S,bound_E,divisions,
                 foursquare_id,foursquare_secret):    
    
    lat_delta = get_delta(bound_N,bound_S,divisions)
    long_delta = get_delta(bound_W,bound_E, divisions)
    
    dist_ns=110574*abs(bound_N-bound_S)
    dist_ew=111320*math.cos(math.radians(bound_N))*abs(bound_E-bound_W)
    
    
    search_params = {
        'client_id': foursquare_id,
        'client_secret': foursquare_secret,
  #      'intent': 'browse',
        'limit': 50,
        'v': '20181209',
        'radius' : math.sqrt(dist_ew*dist_ew+dist_ns*dist_ns)/divisions,
        'sortByDistance': 1
        
    }
    
    print('BBox size {}m x {}m. Search r={}m'.format(dist_ns,dist_ew,search_params['radius']))
    

    search_count = 0

    venues_list=[]
        
    max_response_size=0

    for lat in range(divisions):
        for long in range(divisions):
            
            ne_lat = bound_N + lat * lat_delta
            ne_long = bound_W+ (long+1) * long_delta
            
            #search_params.update({'ne': '{},{}'.format(ne_lat, ne_long),
            #                      'sw': '{},{}'.format(ne_lat - lat_delta,
            #                                           ne_long - long_delta)})                          
            
            search_params.update({'ll': '{},{}'.format(ne_lat-0.5*lat_delta, ne_long-0.5*long_delta)})
  
            items=[]
            
            # print(search_params)
            while True:
                try:
                    r = requests.get('https://api.foursquare.com/v2/venues/explore',
                                 params=search_params)
                except requests.exceptions.RequestException as e:  
                    print(e)    
                    print('Sleeping 10s')
                    time.sleep(10)


                try:
                    resp=r.json()['response']
                except:
                    time.sleep(5)
                    print('retry')
                    continue

                if 'groups' in resp:
                    break
                else:
                    time.sleep(5)
                    print('retry')

            #if 'venues' in r.json()['response']:
            #    venues = r.json()['response']['venues']
            items = r.json()['response']['groups'][0]['items']
            time.sleep(0.6)

            # print('Query returned {} items: {}'.format(len(items),items))
            
            for item in items:
                venue=item['venue']
                categories = venue.get('categories', '')
                if len(categories) == 0:
                   categories = ''
                else:
                    categories = ';'.join([x['name'] for x in categories])
               # print(categories)
                venues_list.append([venue['name'], 
                                    venue['id'],
                    venue['location']['lat'], 
                    venue['location']['lng'],  
                    categories]);

            #print('Search retrieved {} venues.'.format(len(items)))
            max_response_size=max(max_response_size,len(items))

            if len(items) >= search_params['limit']:
                print("Recursive split")
                return getBBoxVenuesNWSE(bound_N,bound_W,bound_S,bound_E,2*divisions,
                 foursquare_id,foursquare_secret) 

            search_count += 1
            if search_count % 50 == 0:
                print(search_count)
         
        # gets fussy when more than 5000 requests/hr
    #        if search_count % 5000 == 0:
    #           time.sleep(60*60)

            

    print('{} Unique Venues Scraped: {}.'.format(
        len(venues_list), datetime.datetime.now()))

    print('Maximum response size {} venues.'.format(max_response_size))
    return venues_list

#df=pd.DataFrame(venues_list)
#df.to_csv('tampere_venues.csv',index=False)
#df

def getCenteredVenues(lat,lng,dist_to_side,divisions,foursquare_id,foursquare_secret):

    # convert distance in meters to latitude/longtitude deltas    
    
    delta_lat=dist_to_side/110574
    delta_lng=dist_to_side/(111320*math.cos(math.radians(lat)))
    
    return getBBoxVenuesNWSE(lat+delta_lat,lng-delta_lng,lat-delta_lat,lng+delta_lng,divisions,
                 foursquare_id,foursquare_secret)

def scrapeNamedCity(city,df,foursquare_id,foursquare_secret):
    from geopy.geocoders import Nominatim

    geolocator = Nominatim(user_agent="my-application")

    while True:
        try:
            location = geolocator.geocode(city)
        except:
            time.sleep(3)
            continue
        else:
            break
            
    lat= location.latitude
    lng = location.longitude
    dist_to_side=3000# meters
    print('The geographical coordinates of {} city centre are {}, {}.'.format(city,lat,lng))
    
    # convert distance in meters to latitude/longtitude deltas    
    
    delta_lat=2*dist_to_side/110574
    delta_lng=2*dist_to_side/(111320*math.cos(math.radians(lat)))
    
    
    divisions=math.ceil(2*25*dist_to_side/3000)

    processed_cities = set()

    if len(df)>0:
        processed_cities=set(df['City'].unique())
  
    for step_lat in range(9):
        for step_long in range(9):
            
            lat_tile = lat + (step_lat-4) * delta_lat
            long_tile = lng + (step_long-4) * delta_lng
            
            city_string = '{}-{}-{}'.format(city,step_lat,step_long)
 
            if city_string in processed_cities:
                print('Skipping {}'.format(city_string))
            else:
                print('Processing {}', format(city_string))
                venues_list=getCenteredVenues(lat_tile,long_tile,dist_to_side,divisions,CLIENT_ID,CLIENT_SECRET)
                if len(venues_list) > 0:
                    dfn=pd.DataFrame(venues_list)
                    print(dfn.shape)
                    dfn.drop_duplicates(inplace=True)
                    dfn.columns=['Name','Id','Latitude','Longtitude','Categories']
                    dfn['City']=city_string

                    print(dfn.shape)

                    if df.size > 0:
                       df=df.append(dfn,ignore_index=True)
                    else:
                       df=dfn
            df.to_csv(FILENAME,index=False)
                        
    return df

# %%
import pandas as pd
import os
import math
import numpy as np # library to handle data in a vectorized manner
# !conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library

# !conda install -c conda-forge geopy --yes 
# uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import matplotlib.cm as cm
import matplotlib.colors as colors


print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Libraries imported.

# %%
CLIENT_ID = 'U1ND1RSESM34E0F5N2VX0WIY1TSNYQM41LXUBM523HOLJXCV' # your Foursquare ID
CLIENT_SECRET = 'X0KNHD5JZDI4XS0TJLWZPZ5AGC44KHUB4J0STYMT2R5MEKPV' # your Foursquare Secret

#kaisa 
CLIENT_ID='HPVS5YBLFPA0AQ1OZOM42KQQ4EHFRUVO1DZS00ENE0HPUI0A'
CLIENT_SECRET='250O40DSBBEP53FPSDEIDBVINQ3VZD4G5SHHHYHPEGIMRGDR'

FILENAME='scraped_venues_tiled.csv'

cities_list=[
    "London, England",
    "Berlin, Germany",
    "Rome, Italy",
    "Birmingham, England",
    "Manchester, England",
]

#cities_list=[
#   "Cremona, Italy"
#]


cities_list_test=['Pori, Finland',"Lappeenranta, Finland"]

df=pd.DataFrame()
try:
    df=pd.read_csv(FILENAME)
except:
    pass

for city in cities_list:
        
    print('city {}'.format(city))
    df=scrapeNamedCity(city,df,CLIENT_ID,CLIENT_SECRET)
    print(df.shape)
    df.to_csv(FILENAME,index=False)
df
# Out:
# city London, England
# The geographical coordinates of London, England city centre are 51.5073219, -0.1276474.
# Skipping London, England-0-0
# Skipping London, England-0-1
# Skipping London, England-0-2
# Skipping London, England-0-3
# Skipping London, England-0-4
# Skipping London, England-0-5
# Skipping London, England-0-6
# Skipping London, England-0-7
# Skipping London, England-0-8
# Skipping London, England-1-0
# Skipping London, England-1-1
# Skipping London, England-1-2
# BBox size 5999.999999999698m x 5996.177739538028m. Search r=169.65158117050106m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# retry
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# retry
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1727 Unique Venues Scraped: 2019-10-15 13:57:08.628021.
# Maximum response size 28 venues.
# (1727, 5)
# (303, 6)
# Processing {} Manchester, England-2-1
# BBox size 5999.999999999698m x 5996.177739538028m. Search r=169.65158117050106m
# 50
# retry
# retry
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# retry
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# retry
# retry
# 900
# retry
# 950
# 1000
# 1050
# 1100
# 1150
# retry
# 1200
# retry
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 612 Unique Venues Scraped: 2019-10-15 14:40:27.373573.
# Maximum response size 9 venues.
# (612, 5)
# (116, 6)
# Processing {} Manchester, England-2-2
# BBox size 5999.999999999698m x 5996.177739538028m. Search r=169.65158117050106m
# 50
# 100
# retry
# 150
# 200
# retry
# 250
# 300
# 350
# 400
# 450
# retry
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# retry
# 900
# 950
# 1000
# retry
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# retry
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 353 Unique Venues Scraped: 2019-10-15 15:23:36.348766.
# Maximum response size 4 venues.
# (353, 5)
# (64, 6)
# Processing {} Manchester, England-2-3
# BBox size 5999.999999999698m x 5996.177739538028m. Search r=169.65158117050106m
# 50
# 100
# 150
# retry
# 200
# 250
# retry
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# retry
# 1500
# 1550
# retry
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# retry
# 2350
# 2400
# 2450
# 2500
# 1382 Unique Venues Scraped: 2019-10-15 16:05:35.869377.
# Maximum response size 28 venues.
# (1382, 5)
# (262, 6)
# Processing {} Manchester, England-2-4
# BBox size 5999.999999999698m x 5996.177739538028m. Search r=169.65158117050106m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# retry
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# retry
# 2000
# 2050
# 2100
# 2150
# 2200
# retry
# 2250
# 2300
# 2350
# retry
# 2400
# 2450
# 2500
# 2158 Unique Venues Scraped: 2019-10-15 16:47:59.343469.
# Maximum response size 19 venues.
# (2158, 5)
# (387, 6)
# Processing {} Manchester, England-2-5
# BBox size 5999.999999999698m x 5996.177739538028m. Search r=169.65158117050106m
# 50
# 100
# 150
# retry
# 200
# 250
# 300
# 350
# 400
# 450
# retry
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# retry
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# retry
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# retry
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1719 Unique Venues Scraped: 2019-10-15 17:30:55.986451.
# Maximum response size 11 venues.
# (1719, 5)
# (317, 6)
# Processing {} Manchester, England-2-6
# BBox size 5999.999999999698m x 5996.177739538028m. Search r=169.65158117050106m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# retry
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# retry
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# retry
# 1550
# 1600
# 1650
# 1700
# 1750
# retry
# 1800
# 1850
# 1900
# 1950
# 2000
# retry
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 693 Unique Venues Scraped: 2019-10-15 18:13:13.220051.
# Maximum response size 7 venues.
# (693, 5)
# (130, 6)
# Processing {} Manchester, England-2-7
# BBox size 5999.999999999698m x 5996.177739538028m. Search r=169.65158117050106m
# retry
# 50
# 100
# 150
# 200
# 250
# retry
# 300
# 350
# 400
# 450
# retry
# retry
# retry
# 500
# retry
# 550
# retry
# retry
# retry
# retry
# 600
# retry
# 650
# 700
# 750
# retry
# retry
# 800
# retry
# retry
# 850
# retry
# retry
# 900
# retry
# 950
# retry
# retry
# retry
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# retry
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# retry
# 1700
# retry
# retry
# 1750
# retry
# 1800
# retry
# 1850
# retry
# 1900
# 1950
# retry
# retry
# 2000
# 2050
# 2100
# retry
# 2150
# retry
# 2200
# 2250
# 2300
# retry
# 2350
# 2400
# 2450
# 2500
# 369 Unique Venues Scraped: 2019-10-15 18:58:05.556577.
# Maximum response size 6 venues.
# (369, 5)
# (69, 6)
# Processing {} Manchester, England-2-8
# BBox size 5999.999999999698m x 5996.177739538028m. Search r=169.65158117050106m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# retry
# retry
# retry
# 450
# retry
# retry
# 500
# retry
# retry
# retry
# 550
# 600
# 650
# retry
# retry
# 700
# retry
# 750
# retry
# 800
# retry
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# retry
# 1600
# retry
# retry
# 1650
# retry
# 1700
# retry
# 1750
# 1800
# retry
# retry
# 1850
# retry
# 1900
# retry
# retry
# 1950
# retry
# 2000
# retry
# retry
# 2050
# retry
# retry
# 2100
# 2150
# 2200
# retry
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 128 Unique Venues Scraped: 2019-10-15 19:42:19.905707.
# Maximum response size 2 venues.
# (128, 5)
# (23, 6)
# Processing {} Manchester, England-3-0
# BBox size 5999.999999999698m x 5996.170170972202m. Search r=169.6514741689599m
# 50
# 100
# 150
# 200
# retry
# retry
# retry
# retry
# 250
# 300
# 350
# retry
# retry
# 400
# retry
# 450
# retry
# 500
# retry
# retry
# retry
# 550
# retry
# retry
# 600
# 650
# retry
# 700
# retry
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# retry
# 1350
# retry
# retry
# retry
# 1400
# retry
# retry
# retry
# 1450
# retry
# 1500
# retry
# 1550
# 1600
# 1650
# retry
# retry
# retry
# retry
# retry
# retry
# 1700
# retry
# retry
# 1750
# retry
# 1800
# retry
# 1850
# retry
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# retry
# 2300
# 2350
# 2400
# 2450
# 2500
# 1117 Unique Venues Scraped: 2019-10-15 20:27:15.879818.
# Maximum response size 11 venues.
# (1117, 5)
# (204, 6)
# Processing {} Manchester, England-3-1
# BBox size 5999.999999999698m x 5996.170170972202m. Search r=169.6514741689599m
# 50
# 100
# retry
# retry
# 150
# 200
# 250
# retry
# 300
# retry
# 350
# retry
# 400
# retry
# 450
# retry
# retry
# retry
# retry
# 500
# retry
# 550
# retry
# 600
# 650
# retry
# 700
# 750
# 800
# 850
# retry
# retry
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# retry
# retry
# 1350
# 1400
# retry
# retry
# 1450
# retry
# retry
# retry
# 1500
# retry
# 1550
# retry
# 1600
# retry
# 1650
# 1700
# 1750
# retry
# retry
# 1800
# 1850
# 1900
# retry
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 608 Unique Venues Scraped: 2019-10-15 21:11:54.443803.
# Maximum response size 14 venues.
# (608, 5)
# (115, 6)
# Processing {} Manchester, England-3-2
# BBox size 5999.999999999698m x 5996.170170972202m. Search r=169.6514741689599m
# retry
# retry
# retry
# 50
# retry
# retry
# retry
# 100
# 150
# retry
# 200
# retry
# 250
# retry
# 300
# retry
# retry
# 350
# 400
# retry
# 450
# retry
# 500
# 550
# retry
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# retry
# retry
# retry
# 1100
# 1150
# retry
# retry
# 1200
# 1250
# retry
# 1300
# 1350
# 1400
# retry
# retry
# 1450
# retry
# retry
# retry
# 1500
# retry
# retry
# retry
# retry
# 1550
# 1600
# 1650
# 1700
# 1750
# retry
# retry
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# retry
# 2100
# 2150
# 2200
# retry
# 2250
# retry
# retry
# retry
# 2300
# retry
# 2350
# retry
# retry
# retry
# 2400
# 2450
# retry
# 2500
# 541 Unique Venues Scraped: 2019-10-15 21:59:56.187562.
# Maximum response size 5 venues.
# (541, 5)
# (99, 6)
# Processing {} Manchester, England-3-3
# BBox size 5999.999999999698m x 5996.170170972202m. Search r=169.6514741689599m
# 50
# 100
# 150
# 200
# 250
# 300
# retry
# 350
# 400
# 450
# retry
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# retry
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# retry
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# retry
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1936 Unique Venues Scraped: 2019-10-15 22:43:09.950990.
# Maximum response size 19 venues.
# (1936, 5)
# (358, 6)
# Processing {} Manchester, England-3-4
# BBox size 5999.999999999698m x 5996.170170972202m. Search r=169.6514741689599m
# 50
# 100
# 150
# 200
# 250
# 300
# retry
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# retry
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# retry
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 3339 Unique Venues Scraped: 2019-10-15 23:25:51.554857.
# Maximum response size 22 venues.
# (3339, 5)
# (628, 6)
# Processing {} Manchester, England-3-5
# BBox size 5999.999999999698m x 5996.170170972202m. Search r=169.6514741689599m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# retry
# 750
# 800
# 850
# 900
# 950
# retry
# retry
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# retry
# 1300
# 1350
# 1400
# retry
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2195 Unique Venues Scraped: 2019-10-16 00:09:19.381093.
# Maximum response size 17 venues.
# (2195, 5)
# (398, 6)
# Processing {} Manchester, England-3-6
# BBox size 5999.999999999698m x 5996.170170972202m. Search r=169.6514741689599m
# 50
# 100
# retry
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# retry
# 2500
# 884 Unique Venues Scraped: 2019-10-16 00:50:58.912647.
# Maximum response size 7 venues.
# (884, 5)
# (158, 6)
# Processing {} Manchester, England-3-7
# BBox size 5999.999999999698m x 5996.1701709722165m. Search r=169.65147416896014m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# retry
# 800
# 850
# retry
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 478 Unique Venues Scraped: 2019-10-16 01:32:02.785185.
# Maximum response size 9 venues.
# (478, 5)
# (89, 6)
# Processing {} Manchester, England-3-8
# BBox size 5999.999999999698m x 5996.170170972232m. Search r=169.65147416896033m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# retry
# 900
# 950
# 1000
# 1050
# 1100
# retry
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# retry
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# retry
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# retry
# 2450
# retry
# 2500
# 47 Unique Venues Scraped: 2019-10-16 02:14:29.240732.
# Maximum response size 2 venues.
# (47, 5)
# (10, 6)
# Processing {} Manchester, England-4-0
# BBox size 5999.999999999698m x 5996.162583060919m. Search r=169.65136689398784m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# retry
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# retry
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 873 Unique Venues Scraped: 2019-10-16 02:55:53.532359.
# Maximum response size 6 venues.
# (873, 5)
# (170, 6)
# Processing {} Manchester, England-4-1
# BBox size 5999.999999999698m x 5996.162583060919m. Search r=169.65136689398784m
# retry
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# retry
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# retry
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# retry
# 1300
# 1350
# retry
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# retry
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 813 Unique Venues Scraped: 2019-10-16 03:38:18.384611.
# Maximum response size 13 venues.
# (813, 5)
# (151, 6)
# Processing {} Manchester, England-4-2
# BBox size 5999.999999999698m x 5996.162583060919m. Search r=169.65136689398784m
# retry
# 50
# 100
# 150
# 200
# retry
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# retry
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# retry
# 1200
# 1250
# retry
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# retry
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# retry
# 2350
# 2400
# 2450
# 2500
# 499 Unique Venues Scraped: 2019-10-16 04:20:49.885171.
# Maximum response size 6 venues.
# (499, 5)
# (101, 6)
# Processing {} Manchester, England-4-3
# BBox size 5999.999999999698m x 5996.162583060919m. Search r=169.65136689398784m
# 50
# 100
# 150
# retry
# 200
# 250
# 300
# retry
# 350
# 400
# 450
# retry
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# retry
# 1800
# retry
# 1850
# 1900
# Recursive split
# BBox size 5999.999999999698m x 5996.162583060919m. Search r=84.82568344699392m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# retry
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# retry
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# retry
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# retry
# 2750
# 2800
# 2850
# 2900
# 2950
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# 3500
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800
# 3850
# 3900
# retry
# 3950
# 4000
# retry
# 4050
# 4100
# 4150
# 4200
# 4250
# 4300
# 4350
# 4400
# 4450
# 4500
# 4550
# 4600
# 4650
# 4700
# 4750
# 4800
# 4850
# 4900
# 4950
# 5000
# 5050
# 5100
# 5150
# 5200
# 5250
# 5300
# 5350
# 5400
# 5450
# 5500
# 5550
# 5600
# retry
# 5650
# 5700
# 5750
# 5800
# 5850
# 5900
# 5950
# 6000
# 6050
# 6100
# 6150
# 6200
# 6250
# 6300
# 6350
# 6400
# 6450
# 6500
# 6550
# retry
# 6600
# 6650
# 6700
# 6750
# 6800
# 6850
# 6900
# 6950
# 7000
# 7050
# 7100
# 7150
# 7200
# 7250
# 7300
# 7350
# 7400
# 7450
# 7500
# 7550
# 7600
# 7650
# 7700
# 7750
# 7800
# 7850
# 7900
# 7950
# 8000
# 8050
# 8100
# 8150
# 8200
# retry
# 8250
# 8300
# 8350
# 8400
# 8450
# 8500
# 8550
# 8600
# 8650
# 8700
# 8750
# 8800
# 8850
# 8900
# 8950
# 9000
# 9050
# 9100
# 9150
# 9200
# retry
# 9250
# 9300
# 9350
# 9400
# 9450
# 9500
# 9550
# 9600
# 9650
# 9700
# 9750
# retry
# 9800
# 9850
# 9900
# 9950
# 10000
# 3315 Unique Venues Scraped: 2019-10-16 07:41:38.532723.
# Maximum response size 41 venues.
# (3315, 5)
# (571, 6)
# Processing {} Manchester, England-4-4
# BBox size 5999.999999999698m x 5996.162583060919m. Search r=169.65136689398784m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# retry
# 1050
# 1100
# Recursive split
# BBox size 5999.999999999698m x 5996.162583060919m. Search r=84.82568344699392m
# 50
# 100
# 150
# 200
# 250
# retry
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# retry
# retry
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# retry
# 2700
# 2750
# 2800
# 2850
# 2900
# 2950
# retry
# 3000
# 3050
# 3100
# 3150
# 3200
# 3250
# 3300
# 3350
# 3400
# 3450
# retry
# 3500
# retry
# 3550
# 3600
# 3650
# 3700
# 3750
# 3800
# 3850
# 3900
# 3950
# 4000
# 4050
# 4100
# 4150
# 4200
# retry
# 4250
# 4300
# retry
# 4350
# 4400
# 4450
# 4500
# 4550
# 4600
# retry
# 4650
# 4700
# 4750
# 4800
# 4850
# retry
# 4900
# 4950
# 5000
# 5050
# 5100
# 5150
# 5200
# 5250
# 5300
# 5350
# 5400
# 5450
# 5500
# 5550
# 5600
# 5650
# 5700
# retry
# 5750
# 5800
# 5850
# 5900
# 5950
# 6000
# 6050
# 6100
# 6150
# 6200
# 6250
# 6300
# 6350
# 6400
# 6450
# 6500
# 6550
# 6600
# 6650
# 6700
# 6750
# retry
# 6800
# 6850
# 6900
# 6950
# 7000
# 7050
# 7100
# 7150
# 7200
# 7250
# retry
# 7300
# 7350
# 7400
# 7450
# 7500
# 7550
# 7600
# 7650
# retry
# 7700
# 7750
# 7800
# 7850
# 7900
# 7950
# 8000
# 8050
# 8100
# 8150
# 8200
# 8250
# 8300
# 8350
# 8400
# 8450
# 8500
# retry
# 8550
# 8600
# 8650
# 8700
# 8750
# 8800
# 8850
# 8900
# 8950
# 9000
# 9050
# retry
# 9100
# 9150
# retry
# 9200
# 9250
# 9300
# 9350
# 9400
# 9450
# 9500
# 9550
# 9600
# 9650
# 9700
# 9750
# 9800
# 9850
# 9900
# 9950
# 10000
# 7715 Unique Venues Scraped: 2019-10-16 10:51:36.227835.
# Maximum response size 22 venues.
# (7715, 5)
# (1323, 6)
# Processing {} Manchester, England-4-5
# BBox size 5999.999999999698m x 5996.162583060919m. Search r=169.65136689398784m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# retry
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# retry
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1969 Unique Venues Scraped: 2019-10-16 11:33:29.210805.
# Maximum response size 14 venues.
# (1969, 5)
# (361, 6)
# Processing {} Manchester, England-4-6
# BBox size 5999.999999999698m x 5996.162583060919m. Search r=169.65136689398784m
# 50
# 100
# 150
# 200
# 250
# retry
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# retry
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# retry
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# retry
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# retry
# retry
# 2250
# retry
# 2300
# 2350
# 2400
# 2450
# 2500
# 1435 Unique Venues Scraped: 2019-10-16 12:17:05.474441.
# Maximum response size 11 venues.
# (1435, 5)
# (256, 6)
# Processing {} Manchester, England-4-7
# BBox size 5999.999999999698m x 5996.162583060919m. Search r=169.65136689398784m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# retry
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 320 Unique Venues Scraped: 2019-10-16 12:59:05.685240.
# Maximum response size 5 venues.
# (320, 5)
# (58, 6)
# Processing {} Manchester, England-4-8
# BBox size 5999.999999999698m x 5996.162583060919m. Search r=169.65136689398784m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# retry
# retry
# retry
# 2300
# 2350
# 2400
# 2450
# 2500
# 88 Unique Venues Scraped: 2019-10-16 13:42:03.095159.
# Maximum response size 2 venues.
# (88, 5)
# (16, 6)
# Processing {} Manchester, England-5-0
# BBox size 5999.999999999698m x 5996.154975716162m. Search r=169.65125934434093m
# 50
# 100
# 150
# retry
# retry
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# retry
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# retry
# 950
# 1000
# 1050
# 1100
# 1150
# retry
# 1200
# 1250
# 1300
# 1350
# retry
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# retry
# 2000
# 2050
# retry
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# retry
# 2500
# 1591 Unique Venues Scraped: 2019-10-16 14:26:35.392352.
# Maximum response size 28 venues.
# (1591, 5)
# (294, 6)
# Processing {} Manchester, England-5-1
# BBox size 5999.999999999698m x 5996.154975716162m. Search r=169.65125934434093m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# retry
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# retry
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1049 Unique Venues Scraped: 2019-10-16 15:08:57.729764.
# Maximum response size 6 venues.
# (1049, 5)
# (192, 6)
# Processing {} Manchester, England-5-2
# BBox size 5999.999999999698m x 5996.154975716162m. Search r=169.65125934434093m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# retry
# retry
# 900
# 950
# 1000
# 1050
# 1100
# retry
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1128 Unique Venues Scraped: 2019-10-16 15:51:40.128828.
# Maximum response size 7 venues.
# (1128, 5)
# (206, 6)
# Processing {} Manchester, England-5-3
# BBox size 5999.999999999698m x 5996.154975716162m. Search r=169.65125934434093m
# 50
# 100
# 150
# 200
# 250
# retry
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# retry
# 700
# 750
# 800
# retry
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# retry
# 1550
# retry
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 996 Unique Venues Scraped: 2019-10-16 16:34:13.768998.
# Maximum response size 6 venues.
# (996, 5)
# (198, 6)
# Processing {} Manchester, England-5-4
# BBox size 5999.999999999698m x 5996.154975716162m. Search r=169.65125934434093m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# retry
# 750
# 800
# 850
# 900
# 950
# retry
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# retry
# retry
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# retry
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# retry
# 2300
# 2350
# 2400
# 2450
# 2500
# 1634 Unique Venues Scraped: 2019-10-16 17:17:04.511071.
# Maximum response size 12 venues.
# (1634, 5)
# (305, 6)
# Processing {} Manchester, England-5-5
# BBox size 5999.999999999698m x 5996.154975716162m. Search r=169.65125934434093m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1846 Unique Venues Scraped: 2019-10-16 17:58:34.351664.
# Maximum response size 15 venues.
# (1846, 5)
# (342, 6)
# Processing {} Manchester, England-5-6
# BBox size 5999.999999999698m x 5996.154975716162m. Search r=169.65125934434093m
# retry
# 50
# retry
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# retry
# 800
# 850
# 900
# 950
# 1000
# 1050
# retry
# 1100
# 1150
# retry
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# retry
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# retry
# 2300
# 2350
# 2400
# 2450
# retry
# 2500
# 865 Unique Venues Scraped: 2019-10-16 18:41:59.053982.
# Maximum response size 6 venues.
# (865, 5)
# (165, 6)
# Processing {} Manchester, England-5-7
# BBox size 5999.999999999698m x 5996.154975716162m. Search r=169.65125934434093m
# 50
# 100
# 150
# 200
# retry
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# retry
# 1450
# retry
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# retry
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 314 Unique Venues Scraped: 2019-10-16 19:24:47.865282.
# Maximum response size 7 venues.
# (314, 5)
# (56, 6)
# Processing {} Manchester, England-5-8
# BBox size 5999.999999999698m x 5996.154975716162m. Search r=169.65125934434093m
# 50
# 100
# 150
# retry
# 200
# 250
# retry
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# retry
# 1000
# 1050
# 1100
# 1150
# retry
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# retry
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# retry
# 2200
# 2250
# retry
# 2300
# 2350
# 2400
# 2450
# 2500
# 47 Unique Venues Scraped: 2019-10-16 20:09:33.346913.
# Maximum response size 2 venues.
# (47, 5)
# (9, 6)
# Processing {} Manchester, England-6-0
# BBox size 5999.999999999698m x 5996.1473488494985m. Search r=169.65115151876955m
# 50
# 100
# 150
# 200
# 250
# retry
# 300
# 350
# 400
# retry
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# retry
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# retry
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# retry
# 2400
# 2450
# 2500
# 659 Unique Venues Scraped: 2019-10-16 20:52:56.902097.
# Maximum response size 9 venues.
# (659, 5)
# (121, 6)
# Processing {} Manchester, England-6-1
# BBox size 5999.999999999698m x 5996.1473488494985m. Search r=169.65115151876955m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# retry
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# retry
# 1050
# retry
# 1100
# 1150
# 1200
# 1250
# retry
# 1300
# retry
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# retry
# retry
# retry
# 2400
# 2450
# 2500
# 979 Unique Venues Scraped: 2019-10-16 21:40:59.127799.
# Maximum response size 19 venues.
# (979, 5)
# (175, 6)
# Processing {} Manchester, England-6-2
# BBox size 5999.999999999698m x 5996.1473488494985m. Search r=169.65115151876955m
# 50
# 100
# 150
# 200
# 250
# 300
# retry
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# retry
# 850
# 900
# 950
# 1000
# 1050
# 1100
# retry
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# retry
# 1850
# 1900
# 1950
# 2000
# 2050
# retry
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# retry
# retry
# 2450
# 2500
# 1879 Unique Venues Scraped: 2019-10-16 22:25:00.710084.
# Maximum response size 17 venues.
# (1879, 5)
# (333, 6)
# Processing {} Manchester, England-6-3
# BBox size 5999.999999999698m x 5996.1473488494985m. Search r=169.65115151876955m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# retry
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# retry
# 2350
# 2400
# 2450
# 2500
# 1560 Unique Venues Scraped: 2019-10-16 23:06:36.241614.
# Maximum response size 20 venues.
# (1560, 5)
# (289, 6)
# Processing {} Manchester, England-6-4
# BBox size 5999.999999999698m x 5996.1473488494985m. Search r=169.65115151876955m
# 50
# 100
# 150
# 200
# 250
# 300
# retry
# retry
# 350
# 400
# 450
# 500
# 550
# HTTPSConnectionPool(host='api.foursquare.com', port=443): Max retries exceeded with url: /v2/venues/explore?client_id=HPVS5YBLFPA0AQ1OZOM42KQQ4EHFRUVO1DZS00ENE0HPUI0A&client_secret=250O40DSBBEP53FPSDEIDBVINQ3VZD4G5SHHHYHPEGIMRGDR&limit=50&v=20181209&radius=169.65115151876955&sortByDistance=1&ll=53.60374987610832%2C-2.2859755184052704 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000002146A5882B0>: Failed to establish a new connection: [WinError 10060] Yhteyden muodostamisyritys epäonnistui, koska vastapuoli ei vastannut oikein määritetyn ajan kuluessa, tai aiemmin muodostettu yhteys epäonnistui, koska palvelin, johon yritettiin muodostaa yhteys, ei vastannut'))
# Sleeping 10s
# HTTPSConnectionPool(host='api.foursquare.com', port=443): Max retries exceeded with url: /v2/venues/explore?client_id=HPVS5YBLFPA0AQ1OZOM42KQQ4EHFRUVO1DZS00ENE0HPUI0A&client_secret=250O40DSBBEP53FPSDEIDBVINQ3VZD4G5SHHHYHPEGIMRGDR&limit=50&v=20181209&radius=169.65115151876955&sortByDistance=1&ll=53.60374987610832%2C-2.284159486476147 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000002146A7DAE80>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Sleeping 10s
# HTTPSConnectionPool(host='api.foursquare.com', port=443): Max retries exceeded with url: /v2/venues/explore?client_id=HPVS5YBLFPA0AQ1OZOM42KQQ4EHFRUVO1DZS00ENE0HPUI0A&client_secret=250O40DSBBEP53FPSDEIDBVINQ3VZD4G5SHHHYHPEGIMRGDR&limit=50&v=20181209&radius=169.65115151876955&sortByDistance=1&ll=53.60374987610832%2C-2.282343454547024 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x000002146A7305C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# Sleeping 10s
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# retry
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1031 Unique Venues Scraped: 2019-10-16 23:50:07.519093.
# Maximum response size 15 venues.
# (1031, 5)
# (199, 6)
# Processing {} Manchester, England-6-5
# BBox size 5999.999999999698m x 5996.1473488494985m. Search r=169.65115151876955m
# retry
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# retry
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# retry
# 1050
# 1100
# 1150
# 1200
# retry
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# retry
# 1550
# retry
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 1145 Unique Venues Scraped: 2019-10-17 00:33:40.434659.
# Maximum response size 11 venues.
# (1145, 5)
# (212, 6)
# Processing {} Manchester, England-6-6
# BBox size 5999.999999999698m x 5996.1473488494985m. Search r=169.65115151876955m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# retry
# 1500
# 1550
# 1600
# 1650
# retry
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# retry
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 586 Unique Venues Scraped: 2019-10-17 01:16:16.748387.
# Maximum response size 10 venues.
# (586, 5)
# (102, 6)
# Processing {} Manchester, England-6-7
# BBox size 5999.999999999698m x 5996.147348849513m. Search r=169.65115151876972m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# retry
# retry
# retry
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# retry
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 210 Unique Venues Scraped: 2019-10-17 01:57:41.687569.
# Maximum response size 6 venues.
# (210, 5)
# (40, 6)
# Processing {} Manchester, England-6-8
# BBox size 5999.999999999698m x 5996.147348849528m. Search r=169.65115151876995m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# retry
# 550
# 600
# 650
# 700
# 750
# 800
# retry
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# retry
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# retry
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# retry
# 2400
# 2450
# 2500
# 257 Unique Venues Scraped: 2019-10-17 02:40:04.785445.
# Maximum response size 7 venues.
# (257, 5)
# (49, 6)
# Processing {} Manchester, England-7-0
# BBox size 5999.999999999698m x 5996.139702371969m. Search r=169.6510434160165m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# retry
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# retry
# 2350
# 2400
# 2450
# 2500
# 945 Unique Venues Scraped: 2019-10-17 03:21:19.680559.
# Maximum response size 15 venues.
# (945, 5)
# (176, 6)
# Processing {} Manchester, England-7-1
# BBox size 5999.999999999698m x 5996.139702371969m. Search r=169.6510434160165m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# retry
# 1000
# retry
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# retry
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# retry
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 92 Unique Venues Scraped: 2019-10-17 04:03:03.204970.
# Maximum response size 2 venues.
# (92, 5)
# (16, 6)
# Processing {} Manchester, England-7-2
# BBox size 5999.999999999698m x 5996.139702371969m. Search r=169.6510434160165m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# retry
# 600
# retry
# 650
# 700
# 750
# 800
# 850
# retry
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# retry
# 1450
# retry
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# retry
# 2150
# 2200
# 2250
# 2300
# retry
# 2350
# 2400
# 2450
# 2500
# 341 Unique Venues Scraped: 2019-10-17 04:45:54.361110.
# Maximum response size 6 venues.
# (341, 5)
# (61, 6)
# Processing {} Manchester, England-7-3
# BBox size 5999.999999999698m x 5996.139702371969m. Search r=169.6510434160165m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# retry
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# retry
# 1550
# 1600
# 1650
# retry
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# retry
# 2500
# 665 Unique Venues Scraped: 2019-10-17 05:27:59.977317.
# Maximum response size 16 venues.
# (665, 5)
# (116, 6)
# Processing {} Manchester, England-7-4
# BBox size 5999.999999999698m x 5996.139702371969m. Search r=169.6510434160165m
# 50
# 100
# retry
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# retry
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# retry
# 2250
# 2300
# 2350
# 2400
# 2450
# retry
# 2500
# 153 Unique Venues Scraped: 2019-10-17 06:10:01.708236.
# Maximum response size 4 venues.
# (153, 5)
# (30, 6)
# Processing {} Manchester, England-7-5
# BBox size 5999.999999999698m x 5996.139702371969m. Search r=169.6510434160165m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# retry
# retry
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# retry
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 693 Unique Venues Scraped: 2019-10-17 06:52:07.192904.
# Maximum response size 10 venues.
# (693, 5)
# (130, 6)
# Processing {} Manchester, England-7-6
# BBox size 5999.999999999698m x 5996.139702371969m. Search r=169.6510434160165m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# retry
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 306 Unique Venues Scraped: 2019-10-17 07:33:36.506439.
# Maximum response size 6 venues.
# (306, 5)
# (56, 6)
# Processing {} Manchester, England-7-7
# BBox size 5999.999999999698m x 5996.139702371984m. Search r=169.65104341601673m
# 50
# 100
# 150
# 200
# 250
# retry
# retry
# 300
# 350
# 400
# 450
# 500
# retry
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# retry
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# retry
# 2250
# 2300
# 2350
# retry
# 2400
# 2450
# 2500
# 151 Unique Venues Scraped: 2019-10-17 08:16:36.893400.
# Maximum response size 3 venues.
# (151, 5)
# (25, 6)
# Processing {} Manchester, England-7-8
# BBox size 5999.999999999698m x 5996.139702371998m. Search r=169.6510434160169m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# retry
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# retry
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# retry
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# retry
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 625 Unique Venues Scraped: 2019-10-17 08:59:28.693177.
# Maximum response size 6 venues.
# (625, 5)
# (109, 6)
# Processing {} Manchester, England-8-0
# BBox size 5999.999999999698m x 5996.132036194128m. Search r=169.65093503481776m
# 50
# retry
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# retry
# 550
# 600
# 650
# retry
# 700
# retry
# retry
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# retry
# 1400
# 1450
# 1500
# retry
# 1550
# 1600
# 1650
# retry
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 563 Unique Venues Scraped: 2019-10-17 09:42:29.467792.
# Maximum response size 4 venues.
# (563, 5)
# (103, 6)
# Processing {} Manchester, England-8-1
# BBox size 5999.999999999698m x 5996.132036194128m. Search r=169.65093503481776m
# 50
# 100
# retry
# 150
# retry
# 200
# 250
# retry
# 300
# 350
# 400
# 450
# retry
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# retry
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 513 Unique Venues Scraped: 2019-10-17 10:25:00.966735.
# Maximum response size 7 venues.
# (513, 5)
# (97, 6)
# Processing {} Manchester, England-8-2
# BBox size 5999.999999999698m x 5996.132036194128m. Search r=169.65093503481776m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# retry
# 1100
# 1150
# retry
# 1200
# 1250
# retry
# 1300
# 1350
# 1400
# 1450
# retry
# 1500
# retry
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# retry
# 2000
# 2050
# retry
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 365 Unique Venues Scraped: 2019-10-17 11:07:29.161547.
# Maximum response size 6 venues.
# (365, 5)
# (73, 6)
# Processing {} Manchester, England-8-3
# BBox size 5999.999999999698m x 5996.132036194128m. Search r=169.65093503481776m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 475 Unique Venues Scraped: 2019-10-17 11:49:15.219731.
# Maximum response size 5 venues.
# (475, 5)
# (86, 6)
# Processing {} Manchester, England-8-4
# BBox size 5999.999999999698m x 5996.132036194128m. Search r=169.65093503481776m
# 50
# retry
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# retry
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# retry
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# retry
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# retry
# 2400
# 2450
# 2500
# 376 Unique Venues Scraped: 2019-10-17 12:34:18.902678.
# Maximum response size 5 venues.
# (376, 5)
# (79, 6)
# Processing {} Manchester, England-8-5
# BBox size 5999.999999999698m x 5996.132036194128m. Search r=169.65093503481776m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# retry
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# retry
# 1750
# 1800
# 1850
# retry
# retry
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# retry
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 166 Unique Venues Scraped: 2019-10-17 13:18:11.251675.
# Maximum response size 4 venues.
# (166, 5)
# (34, 6)
# Processing {} Manchester, England-8-6
# BBox size 5999.999999999698m x 5996.132036194128m. Search r=169.65093503481776m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# retry
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 348 Unique Venues Scraped: 2019-10-17 14:00:06.326571.
# Maximum response size 7 venues.
# (348, 5)
# (60, 6)
# Processing {} Manchester, England-8-7
# BBox size 5999.999999999698m x 5996.132036194113m. Search r=169.6509350348176m
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# retry
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# retry
# retry
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
#